# %% [markdown]
# <a href="https://colab.research.google.com/github/alejagamez26/DS/blob/main/Estilizacion_de_tablas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Data Visualization: Estilizando tablas con python**

# %% [markdown]
# ## **Extracción y preparación de los datos**

# %%
#!pip install pandas==2.0.0

# %%
import pandas as pd

# %%
print(pd.__version__)
# Out:
# 2.2.2

# %%
ventas = pd.read_csv('https://gist.githubusercontent.com/ahcamachod/d2efadda3f3833d65da750c64705ac42/raw/80aef6f3bad210d34b67ed85565f039a30e2d9e0/ventas.csv', sep='#')
ventas.head()
# Out:
#   fecha_pedido fecha_envio        modo_envio    nombre_cliente  \
# 0   2018-11-09  2018-11-12         Económica  Gaspar Fernández
# 1   2018-11-09  2018-11-12         Económica  Gaspar Fernández
# 2   2018-06-13  2018-06-17         Económica   Matías González
# 3   2017-10-12  2017-10-19  Entrega estándar    Lucas González
# 4   2017-10-12  2017-10-19  Entrega estándar    Lucas González
#
#   segmento_cliente           ciudad     provincia        region  \
# 0              B2C  Lomas de Zamora  Buenos Aires  Buenos Aires
# 1              B2C  Lomas de Zamora  Buenos Aires  Buenos Aires
# 2              B2B          Córdoba       Córdoba       Central
# 3              B2C        Gualeguay    Entre Ríos       Litoral
# 4              B2C        Gualeguay    Entre Ríos       Litoral
#
#                  departamento                tipo_producto  precio_base  \
# 0  Materiales de construcción                   Fontanería       409.70
# 1  Materiales de construcción                 Herramientas       705.10
# 2     Jardinería y paisajismo                     Semillas        19.02
# 3  Materiales de construcción  Materiales de revestimiento       781.38
# 4     Jardinería y paisajismo                      Macetas        35.88
#
#    precio_unit_sin_descuento  descuento  precio_unit_venta  cantidad   ventas  \
# 0                     445.33      0.000             445.33         2   890.66
# 1                     829.53      0.000             829.53         3  2488.59
# 2                      24.86      0.000              24.86         2    49.72
# 3                     840.19      0.225             651.15         5  3255.75
# 4                      42.24      0.100              38.02         2    76.04
#
#    ganancia
# 0     71.26
# 1    373.29
# 2     11.68
# 3   -651.15
# 4      4.28

# %%
ventas = ventas[["fecha_pedido", "modo_envio", "nombre_cliente", "segmento_cliente", "ciudad", "provincia", "region", "departamento", "tipo_producto", "ventas", "cantidad", "ganancia"]]
ventas.head(2)
# Out:
#   fecha_pedido modo_envio    nombre_cliente segmento_cliente           ciudad  \
# 0   2018-11-09  Económica  Gaspar Fernández              B2C  Lomas de Zamora
# 1   2018-11-09  Económica  Gaspar Fernández              B2C  Lomas de Zamora
#
#       provincia        region                departamento tipo_producto  \
# 0  Buenos Aires  Buenos Aires  Materiales de construcción    Fontanería
# 1  Buenos Aires  Buenos Aires  Materiales de construcción  Herramientas
#
#     ventas  cantidad  ganancia
# 0   890.66         2     71.26
# 1  2488.59         3    373.29

# %%
ventas.shape
# Out:
# (8940, 12)

# %%
ventas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8940 entries, 0 to 8939
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   fecha_pedido      8940 non-null   object
#  1   modo_envio        8940 non-null   object
#  2   nombre_cliente    8940 non-null   object
#  3   segmento_cliente  8940 non-null   object
#  4   ciudad            8940 non-null   object
#  5   provincia         8940 non-null   object
#  6   region            8940 non-null   object
#  7   departamento      8940 non-null   object
#  8   tipo_producto     8940 non-null   object
#  9   ventas            8940 non-null   float64
#  10  cantidad          8940 non-null   int64
#  11  ganancia          8940 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 838.3+ KB

# %%
ventas["fecha_pedido"] = pd.to_datetime(ventas["fecha_pedido"])
ventas.head()
# Out:
#   fecha_pedido        modo_envio    nombre_cliente segmento_cliente  \
# 0   2018-11-09         Económica  Gaspar Fernández              B2C
# 1   2018-11-09         Económica  Gaspar Fernández              B2C
# 2   2018-06-13         Económica   Matías González              B2B
# 3   2017-10-12  Entrega estándar    Lucas González              B2C
# 4   2017-10-12  Entrega estándar    Lucas González              B2C
#
#             ciudad     provincia        region                departamento  \
# 0  Lomas de Zamora  Buenos Aires  Buenos Aires  Materiales de construcción
# 1  Lomas de Zamora  Buenos Aires  Buenos Aires  Materiales de construcción
# 2          Córdoba       Córdoba       Central     Jardinería y paisajismo
# 3        Gualeguay    Entre Ríos       Litoral  Materiales de construcción
# 4        Gualeguay    Entre Ríos       Litoral     Jardinería y paisajismo
#
#                  tipo_producto   ventas  cantidad  ganancia
# 0                   Fontanería   890.66         2     71.26
# 1                 Herramientas  2488.59         3    373.29
# 2                     Semillas    49.72         2     11.68
# 3  Materiales de revestimiento  3255.75         5   -651.15
# 4                      Macetas    76.04         2      4.28

# %%
ventas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8940 entries, 0 to 8939
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   fecha_pedido      8940 non-null   datetime64[ns]
#  1   modo_envio        8940 non-null   object
#  2   nombre_cliente    8940 non-null   object
#  3   segmento_cliente  8940 non-null   object
#  4   ciudad            8940 non-null   object
#  5   provincia         8940 non-null   object
#  6   region            8940 non-null   object
#  7   departamento      8940 non-null   object
#  8   tipo_producto     8940 non-null   object
#  9   ventas            8940 non-null   float64
#  10  cantidad          8940 non-null   int64
#  11  ganancia          8940 non-null   float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(8)
# memory usage: 838.3+ KB

# %% [markdown]
# ## Misión 1: Equipo de Ventas
#
# Necesitamos construir una visualización para indicar los **10 principales clientes por total de ventas**.
#
# Con ello, el equipo de ventas puede pensar en estrategias para mantener a estos clientes comprando en nuestra tienda.

# %%
clientes = ventas.groupby(["nombre_cliente"])["ventas"].sum().nlargest(10).copy().reset_index()
clientes
# Out:
#       nombre_cliente    ventas
# 0    Víctor Carrasco  73370.61
# 1        Brisa Rojas  68868.11
# 2       Mateo Vargas  62749.75
# 3      Vicente Rojas  59544.11
# 4        Laura Rojas  51398.87
# 5         Lucía Díaz  48178.99
# 6   Cristina Barrios  47610.80
# 7  Alejandro Sánchez  43769.25
# 8      Pamela Huerta  42354.19
# 9     Carlos Sánchez  41238.81

# %%
# Otra manera de hacerlo: creando un diccionario
# dic = {"nombre_cliente":"Clientes", "ventas":"Ventas"}
# clientes = clientes.rename(columns=dic)

clientes.columns = ["Clientes", "Ventas"]
clientes["Ranking"] = clientes.index + 1
clientes.set_index("Ranking", inplace=True)
clientes
# Out:
#                   Clientes    Ventas
# Ranking
# 2          Víctor Carrasco  73370.61
# 3              Brisa Rojas  68868.11
# 4             Mateo Vargas  62749.75
# 5            Vicente Rojas  59544.11
# 6              Laura Rojas  51398.87
# 7               Lucía Díaz  48178.99
# 8         Cristina Barrios  47610.80
# 9        Alejandro Sánchez  43769.25
# 10           Pamela Huerta  42354.19
# 11          Carlos Sánchez  41238.81

# %%
# Creamos el objeto estilo y trabajamos desde ahí las modificaciones de estilo

estilo =  clientes.style
estilo
# Out:
# <style type="text/css">
# </style>
# <table id="T_0e1db" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0e1db_level0_col0" class="col_heading level0 col0" >Clientes</th>
#       <th id="T_0e1db_level0_col1" class="col_heading level0 col1" >Ventas</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Ranking</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0e1db_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_0e1db_row0_col0" class="data row0 col0" >Víctor Carrasco</td>
#       <td id="T_0e1db_row0_col1" class="data row0 col1" >73370.610000</td>
#     </tr>
#     <tr>
#       <th id="T_0e1db_level0_row1" class="row_heading level0 row1" >3</th>
#       <td id="T_0e1db_row1_col0" class="data row1 col0" >Brisa Rojas</td>
#       <td id="T_0e1db_row1_col1" class="data row1 col1" >68868.110000</td>
#     </tr>
#     <tr>
#       <th id="T_0e1db_level0_row2" class="row_heading level0 row2" >4</th>
#       <td id="T_0e1db_row2_col0" class="data row2 col0" >Mateo Vargas</td>
#       <td id="T_0e1db_row2_col1" class="data row2 col1" >62749.750000</td>
#     </tr>
#     <tr>
#       <th id="T_0e1db_level0_row3" class="row_heading level0 row3" >5</th>
#       <td id="T_0e1db_row3_col0" class="data row3 col0" >Vicente Rojas</td>
#       <td id="T_0e1db_row3_col1" class="data row3 col1" >59544.110000</td>
#     </tr>
#     <tr>
#       <th id="T_0e1db_level0_row4" class="row_heading level0 row4" >6</th>
#       <td id="T_0e1db_row4_col0" class="data row4 col0" >Laura Rojas</td>
#       <td id="T_0e1db_row4_col1" class="data row4 col1" >51398.870000</td>
#     </tr>
#     <tr>
#       <th id="T_0e1db_level0_row5" class="row_heading level0 row5" >7</th>
#       <td id="T_0e1db_row5_col0" class="data row5 col0" >Lucía Díaz</td>
#       <td id="T_0e1db_row5_col1" class="data row5 col1" >48178.990000</td>
#     </tr>
#     <tr>
#       <th id="T_0e1db_level0_row6" class="row_heading level0 row6" >8</th>
#       <td id="T_0e1db_row6_col0" class="data row6 col0" >Cristina Barrios</td>
#       <td id="T_0e1db_row6_col1" class="data row6 col1" >47610.800000</td>
#     </tr>
#     <tr>
#       <th id="T_0e1db_level0_row7" class="row_heading level0 row7" >9</th>
#       <td id="T_0e1db_row7_col0" class="data row7 col0" >Alejandro Sánchez</td>
#       <td id="T_0e1db_row7_col1" class="data row7 col1" >43769.250000</td>
#     </tr>
#     <tr>
#       <th id="T_0e1db_level0_row8" class="row_heading level0 row8" >10</th>
#       <td id="T_0e1db_row8_col0" class="data row8 col0" >Pamela Huerta</td>
#       <td id="T_0e1db_row8_col1" class="data row8 col1" >42354.190000</td>
#     </tr>
#     <tr>
#       <th id="T_0e1db_level0_row9" class="row_heading level0 row9" >11</th>
#       <td id="T_0e1db_row9_col0" class="data row9 col0" >Carlos Sánchez</td>
#       <td id="T_0e1db_row9_col1" class="data row9 col1" >41238.810000</td>
#     </tr>
#   </tbody>
# </table>

# %%
estilo.format({"Ventas":"{:,.2f}"})
estilo
# Out:
# <style type="text/css">
# </style>
# <table id="T_0e1db" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0e1db_level0_col0" class="col_heading level0 col0" >Clientes</th>
#       <th id="T_0e1db_level0_col1" class="col_heading level0 col1" >Ventas</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Ranking</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0e1db_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_0e1db_row0_col0" class="data row0 col0" >Víctor Carrasco</td>
#       <td id="T_0e1db_row0_col1" class="data row0 col1" >73,370.61</td>
#     </tr>
#     <tr>
#       <th id="T_0e1db_level0_row1" class="row_heading level0 row1" >3</th>
#       <td id="T_0e1db_row1_col0" class="data row1 col0" >Brisa Rojas</td>
#       <td id="T_0e1db_row1_col1" class="data row1 col1" >68,868.11</td>
#     </tr>
#     <tr>
#       <th id="T_0e1db_level0_row2" class="row_heading level0 row2" >4</th>
#       <td id="T_0e1db_row2_col0" class="data row2 col0" >Mateo Vargas</td>
#       <td id="T_0e1db_row2_col1" class="data row2 col1" >62,749.75</td>
#     </tr>
#     <tr>
#       <th id="T_0e1db_level0_row3" class="row_heading level0 row3" >5</th>
#       <td id="T_0e1db_row3_col0" class="data row3 col0" >Vicente Rojas</td>
#       <td id="T_0e1db_row3_col1" class="data row3 col1" >59,544.11</td>
#     </tr>
#     <tr>
#       <th id="T_0e1db_level0_row4" class="row_heading level0 row4" >6</th>
#       <td id="T_0e1db_row4_col0" class="data row4 col0" >Laura Rojas</td>
#       <td id="T_0e1db_row4_col1" class="data row4 col1" >51,398.87</td>
#     </tr>
#     <tr>
#       <th id="T_0e1db_level0_row5" class="row_heading level0 row5" >7</th>
#       <td id="T_0e1db_row5_col0" class="data row5 col0" >Lucía Díaz</td>
#       <td id="T_0e1db_row5_col1" class="data row5 col1" >48,178.99</td>
#     </tr>
#     <tr>
#       <th id="T_0e1db_level0_row6" class="row_heading level0 row6" >8</th>
#       <td id="T_0e1db_row6_col0" class="data row6 col0" >Cristina Barrios</td>
#       <td id="T_0e1db_row6_col1" class="data row6 col1" >47,610.80</td>
#     </tr>
#     <tr>
#       <th id="T_0e1db_level0_row7" class="row_heading level0 row7" >9</th>
#       <td id="T_0e1db_row7_col0" class="data row7 col0" >Alejandro Sánchez</td>
#       <td id="T_0e1db_row7_col1" class="data row7 col1" >43,769.25</td>
#     </tr>
#     <tr>
#       <th id="T_0e1db_level0_row8" class="row_heading level0 row8" >10</th>
#       <td id="T_0e1db_row8_col0" class="data row8 col0" >Pamela Huerta</td>
#       <td id="T_0e1db_row8_col1" class="data row8 col1" >42,354.19</td>
#     </tr>
#     <tr>
#       <th id="T_0e1db_level0_row9" class="row_heading level0 row9" >11</th>
#       <td id="T_0e1db_row9_col0" class="data row9 col0" >Carlos Sánchez</td>
#       <td id="T_0e1db_row9_col1" class="data row9 col1" >41,238.81</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Misión 2: Equipo Comercial
#
# Necesitamos construir una visualización que permita asociar el **total de ganancias en ventas y el total de lucros por tipo de producto**.
#
# Ello permitirá que el equipo comercial pueda enfocarse en estrategias para apalancar los ingresos que se reciben con cada tipo de producto vendido en la tienda.

# %%
ganancias_ventas = ventas.groupby(["tipo_producto"])[["ventas", "ganancia"]].sum()
ganancias_ventas
# Out:
#                                  ventas  ganancia
# tipo_producto
# Brotes                          8811.32   1381.42
# Decoración de jardín           82680.08   9939.43
# Equipos de limpieza           542304.58   8724.39
# Fertilizantes                  53144.74  11254.88
# Fontanería                    373223.88  -5622.34
# Herramientas                  995158.41  41020.34
# Herramientas automotrices     502109.29  63330.22
# Herramientas de jardinería    648879.72  53202.88
# Iluminación                   275229.53  20264.54
# Macetas                       696044.18  33941.85
# Materiales de paisajismo      150552.49  -1912.37
# Materiales de revestimiento   629656.36 -28869.01
# Muebles de exterior           328932.27  26784.59
# Neumáticos                   1022428.97  67460.05
# Pesticidas                    244956.04  53343.89
# Piezas de repuesto            486907.94  91148.67
# Semillas                       39979.75   8865.09

# %%
ganancias_ventas.index.name = "Tipo de Producto"
ganancias_ventas
# Out:
#                                  ventas  ganancia
# Tipo de Producto
# Brotes                          8811.32   1381.42
# Decoración de jardín           82680.08   9939.43
# Equipos de limpieza           542304.58   8724.39
# Fertilizantes                  53144.74  11254.88
# Fontanería                    373223.88  -5622.34
# Herramientas                  995158.41  41020.34
# Herramientas automotrices     502109.29  63330.22
# Herramientas de jardinería    648879.72  53202.88
# Iluminación                   275229.53  20264.54
# Macetas                       696044.18  33941.85
# Materiales de paisajismo      150552.49  -1912.37
# Materiales de revestimiento   629656.36 -28869.01
# Muebles de exterior           328932.27  26784.59
# Neumáticos                   1022428.97  67460.05
# Pesticidas                    244956.04  53343.89
# Piezas de repuesto            486907.94  91148.67
# Semillas                       39979.75   8865.09

# %%
estilo_producto = ganancias_ventas.style

# %%
estilo_producto.format("USD {:,.2f}")
estilo_producto
# Out:
# <style type="text/css">
# </style>
# <table id="T_55212" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_55212_level0_col0" class="col_heading level0 col0" >ventas</th>
#       <th id="T_55212_level0_col1" class="col_heading level0 col1" >ganancia</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Tipo de Producto</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_55212_level0_row0" class="row_heading level0 row0" >Brotes</th>
#       <td id="T_55212_row0_col0" class="data row0 col0" >USD 8,811.32</td>
#       <td id="T_55212_row0_col1" class="data row0 col1" >USD 1,381.42</td>
#     </tr>
#     <tr>
#       <th id="T_55212_level0_row1" class="row_heading level0 row1" >Decoración de jardín</th>
#       <td id="T_55212_row1_col0" class="data row1 col0" >USD 82,680.08</td>
#       <td id="T_55212_row1_col1" class="data row1 col1" >USD 9,939.43</td>
#     </tr>
#     <tr>
#       <th id="T_55212_level0_row2" class="row_heading level0 row2" >Equipos de limpieza</th>
#       <td id="T_55212_row2_col0" class="data row2 col0" >USD 542,304.58</td>
#       <td id="T_55212_row2_col1" class="data row2 col1" >USD 8,724.39</td>
#     </tr>
#     <tr>
#       <th id="T_55212_level0_row3" class="row_heading level0 row3" >Fertilizantes</th>
#       <td id="T_55212_row3_col0" class="data row3 col0" >USD 53,144.74</td>
#       <td id="T_55212_row3_col1" class="data row3 col1" >USD 11,254.88</td>
#     </tr>
#     <tr>
#       <th id="T_55212_level0_row4" class="row_heading level0 row4" >Fontanería</th>
#       <td id="T_55212_row4_col0" class="data row4 col0" >USD 373,223.88</td>
#       <td id="T_55212_row4_col1" class="data row4 col1" >USD -5,622.34</td>
#     </tr>
#     <tr>
#       <th id="T_55212_level0_row5" class="row_heading level0 row5" >Herramientas</th>
#       <td id="T_55212_row5_col0" class="data row5 col0" >USD 995,158.41</td>
#       <td id="T_55212_row5_col1" class="data row5 col1" >USD 41,020.34</td>
#     </tr>
#     <tr>
#       <th id="T_55212_level0_row6" class="row_heading level0 row6" >Herramientas automotrices</th>
#       <td id="T_55212_row6_col0" class="data row6 col0" >USD 502,109.29</td>
#       <td id="T_55212_row6_col1" class="data row6 col1" >USD 63,330.22</td>
#     </tr>
#     <tr>
#       <th id="T_55212_level0_row7" class="row_heading level0 row7" >Herramientas de jardinería</th>
#       <td id="T_55212_row7_col0" class="data row7 col0" >USD 648,879.72</td>
#       <td id="T_55212_row7_col1" class="data row7 col1" >USD 53,202.88</td>
#     </tr>
#     <tr>
#       <th id="T_55212_level0_row8" class="row_heading level0 row8" >Iluminación</th>
#       <td id="T_55212_row8_col0" class="data row8 col0" >USD 275,229.53</td>
#       <td id="T_55212_row8_col1" class="data row8 col1" >USD 20,264.54</td>
#     </tr>
#     <tr>
#       <th id="T_55212_level0_row9" class="row_heading level0 row9" >Macetas</th>
#       <td id="T_55212_row9_col0" class="data row9 col0" >USD 696,044.18</td>
#       <td id="T_55212_row9_col1" class="data row9 col1" >USD 33,941.85</td>
#     </tr>
#     <tr>
#       <th id="T_55212_level0_row10" class="row_heading level0 row10" >Materiales de paisajismo</th>
#       <td id="T_55212_row10_col0" class="data row10 col0" >USD 150,552.49</td>
#       <td id="T_55212_row10_col1" class="data row10 col1" >USD -1,912.37</td>
#     </tr>
#     <tr>
#       <th id="T_55212_level0_row11" class="row_heading level0 row11" >Materiales de revestimiento</th>
#       <td id="T_55212_row11_col0" class="data row11 col0" >USD 629,656.36</td>
#       <td id="T_55212_row11_col1" class="data row11 col1" >USD -28,869.01</td>
#     </tr>
#     <tr>
#       <th id="T_55212_level0_row12" class="row_heading level0 row12" >Muebles de exterior</th>
#       <td id="T_55212_row12_col0" class="data row12 col0" >USD 328,932.27</td>
#       <td id="T_55212_row12_col1" class="data row12 col1" >USD 26,784.59</td>
#     </tr>
#     <tr>
#       <th id="T_55212_level0_row13" class="row_heading level0 row13" >Neumáticos</th>
#       <td id="T_55212_row13_col0" class="data row13 col0" >USD 1,022,428.97</td>
#       <td id="T_55212_row13_col1" class="data row13 col1" >USD 67,460.05</td>
#     </tr>
#     <tr>
#       <th id="T_55212_level0_row14" class="row_heading level0 row14" >Pesticidas</th>
#       <td id="T_55212_row14_col0" class="data row14 col0" >USD 244,956.04</td>
#       <td id="T_55212_row14_col1" class="data row14 col1" >USD 53,343.89</td>
#     </tr>
#     <tr>
#       <th id="T_55212_level0_row15" class="row_heading level0 row15" >Piezas de repuesto</th>
#       <td id="T_55212_row15_col0" class="data row15 col0" >USD 486,907.94</td>
#       <td id="T_55212_row15_col1" class="data row15 col1" >USD 91,148.67</td>
#     </tr>
#     <tr>
#       <th id="T_55212_level0_row16" class="row_heading level0 row16" >Semillas</th>
#       <td id="T_55212_row16_col0" class="data row16 col0" >USD 39,979.75</td>
#       <td id="T_55212_row16_col1" class="data row16 col1" >USD 8,865.09</td>
#     </tr>
#   </tbody>
# </table>

# %%
estilo_producto.format("USD {:,.2f}").highlight_max(color="lightgreen").highlight_min(color="lightred")
estilo_producto
# Out:
# <style type="text/css">
# #T_55212_row0_col0, #T_55212_row11_col1 {
#   background-color: red;
#   background-color: lightred;
# }
# #T_55212_row13_col0, #T_55212_row15_col1 {
#   background-color: lightgreen;
#   background-color: lightgreen;
# }
# </style>
# <table id="T_55212" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_55212_level0_col0" class="col_heading level0 col0" >ventas</th>
#       <th id="T_55212_level0_col1" class="col_heading level0 col1" >ganancia</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Tipo de Producto</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_55212_level0_row0" class="row_heading level0 row0" >Brotes</th>
#       <td id="T_55212_row0_col0" class="data row0 col0" >USD 8,811.32</td>
#       <td id="T_55212_row0_col1" class="data row0 col1" >USD 1,381.42</td>
#     </tr>
#     <tr>
#       <th id="T_55212_level0_row1" class="row_heading level0 row1" >Decoración de jardín</th>
#       <td id="T_55212_row1_col0" class="data row1 col0" >USD 82,680.08</td>
#       <td id="T_55212_row1_col1" class="data row1 col1" >USD 9,939.43</td>
#     </tr>
#     <tr>
#       <th id="T_55212_level0_row2" class="row_heading level0 row2" >Equipos de limpieza</th>
#       <td id="T_55212_row2_col0" class="data row2 col0" >USD 542,304.58</td>
#       <td id="T_55212_row2_col1" class="data row2 col1" >USD 8,724.39</td>
#     </tr>
#     <tr>
#       <th id="T_55212_level0_row3" class="row_heading level0 row3" >Fertilizantes</th>
#       <td id="T_55212_row3_col0" class="data row3 col0" >USD 53,144.74</td>
#       <td id="T_55212_row3_col1" class="data row3 col1" >USD 11,254.88</td>
#     </tr>
#     <tr>
#       <th id="T_55212_level0_row4" class="row_heading level0 row4" >Fontanería</th>
#       <td id="T_55212_row4_col0" class="data row4 col0" >USD 373,223.88</td>
#       <td id="T_55212_row4_col1" class="data row4 col1" >USD -5,622.34</td>
#     </tr>
#     <tr>
#       <th id="T_55212_level0_row5" class="row_heading level0 row5" >Herramientas</th>
#       <td id="T_55212_row5_col0" class="data row5 col0" >USD 995,158.41</td>
#       <td id="T_55212_row5_col1" class="data row5 col1" >USD 41,020.34</td>
#     </tr>
#     <tr>
#       <th id="T_55212_level0_row6" class="row_heading level0 row6" >Herramientas automotrices</th>
#       <td id="T_55212_row6_col0" class="data row6 col0" >USD 502,109.29</td>
#       <td id="T_55212_row6_col1" class="data row6 col1" >USD 63,330.22</td>
#     </tr>
#     <tr>
#       <th id="T_55212_level0_row7" class="row_heading level0 row7" >Herramientas de jardinería</th>
#       <td id="T_55212_row7_col0" class="data row7 col0" >USD 648,879.72</td>
#       <td id="T_55212_row7_col1" class="data row7 col1" >USD 53,202.88</td>
#     </tr>
#     <tr>
#       <th id="T_55212_level0_row8" class="row_heading level0 row8" >Iluminación</th>
#       <td id="T_55212_row8_col0" class="data row8 col0" >USD 275,229.53</td>
#       <td id="T_55212_row8_col1" class="data row8 col1" >USD 20,264.54</td>
#     </tr>
#     <tr>
#       <th id="T_55212_level0_row9" class="row_heading level0 row9" >Macetas</th>
#       <td id="T_55212_row9_col0" class="data row9 col0" >USD 696,044.18</td>
#       <td id="T_55212_row9_col1" class="data row9 col1" >USD 33,941.85</td>
#     </tr>
#     <tr>
#       <th id="T_55212_level0_row10" class="row_heading level0 row10" >Materiales de paisajismo</th>
#       <td id="T_55212_row10_col0" class="data row10 col0" >USD 150,552.49</td>
#       <td id="T_55212_row10_col1" class="data row10 col1" >USD -1,912.37</td>
#     </tr>
#     <tr>
#       <th id="T_55212_level0_row11" class="row_heading level0 row11" >Materiales de revestimiento</th>
#       <td id="T_55212_row11_col0" class="data row11 col0" >USD 629,656.36</td>
#       <td id="T_55212_row11_col1" class="data row11 col1" >USD -28,869.01</td>
#     </tr>
#     <tr>
#       <th id="T_55212_level0_row12" class="row_heading level0 row12" >Muebles de exterior</th>
#       <td id="T_55212_row12_col0" class="data row12 col0" >USD 328,932.27</td>
#       <td id="T_55212_row12_col1" class="data row12 col1" >USD 26,784.59</td>
#     </tr>
#     <tr>
#       <th id="T_55212_level0_row13" class="row_heading level0 row13" >Neumáticos</th>
#       <td id="T_55212_row13_col0" class="data row13 col0" >USD 1,022,428.97</td>
#       <td id="T_55212_row13_col1" class="data row13 col1" >USD 67,460.05</td>
#     </tr>
#     <tr>
#       <th id="T_55212_level0_row14" class="row_heading level0 row14" >Pesticidas</th>
#       <td id="T_55212_row14_col0" class="data row14 col0" >USD 244,956.04</td>
#       <td id="T_55212_row14_col1" class="data row14 col1" >USD 53,343.89</td>
#     </tr>
#     <tr>
#       <th id="T_55212_level0_row15" class="row_heading level0 row15" >Piezas de repuesto</th>
#       <td id="T_55212_row15_col0" class="data row15 col0" >USD 486,907.94</td>
#       <td id="T_55212_row15_col1" class="data row15 col1" >USD 91,148.67</td>
#     </tr>
#     <tr>
#       <th id="T_55212_level0_row16" class="row_heading level0 row16" >Semillas</th>
#       <td id="T_55212_row16_col0" class="data row16 col0" >USD 39,979.75</td>
#       <td id="T_55212_row16_col1" class="data row16 col1" >USD 8,865.09</td>
#     </tr>
#   </tbody>
# </table>

# %%
estilo_producto.background_gradient(cmap="Greens")
estilo_producto
# Out:
# <style type="text/css">
# #T_55212_row0_col0, #T_55212_row11_col1 {
#   background-color: red;
#   background-color: lightred;
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_55212_row0_col1 {
#   background-color: #c7e9c0;
#   color: #000000;
# }
# #T_55212_row1_col0 {
#   background-color: #edf8e9;
#   color: #000000;
# }
# #T_55212_row1_col1 {
#   background-color: #b1e0ab;
#   color: #000000;
# }
# #T_55212_row2_col0 {
#   background-color: #6abf71;
#   color: #000000;
# }
# #T_55212_row2_col1, #T_55212_row12_col0, #T_55212_row16_col1 {
#   background-color: #b4e1ad;
#   color: #000000;
# }
# #T_55212_row3_col0 {
#   background-color: #f1faee;
#   color: #000000;
# }
# #T_55212_row3_col1 {
#   background-color: #aedea7;
#   color: #000000;
# }
# #T_55212_row4_col0 {
#   background-color: #a5db9f;
#   color: #000000;
# }
# #T_55212_row4_col1 {
#   background-color: #d5efcf;
#   color: #000000;
# }
# #T_55212_row5_col0 {
#   background-color: #004c1e;
#   color: #f1f1f1;
# }
# #T_55212_row5_col1 {
#   background-color: #52b365;
#   color: #f1f1f1;
# }
# #T_55212_row6_col0 {
#   background-color: #79c67a;
#   color: #000000;
# }
# #T_55212_row6_col1 {
#   background-color: #1e8741;
#   color: #f1f1f1;
# }
# #T_55212_row7_col0 {
#   background-color: #3fa95c;
#   color: #f1f1f1;
# }
# #T_55212_row7_col1, #T_55212_row14_col1 {
#   background-color: #329b51;
#   color: #f1f1f1;
# }
# #T_55212_row8_col0 {
#   background-color: #c3e7bc;
#   color: #000000;
# }
# #T_55212_row8_col1 {
#   background-color: #95d391;
#   color: #000000;
# }
# #T_55212_row9_col0 {
#   background-color: #349d53;
#   color: #f1f1f1;
# }
# #T_55212_row9_col1 {
#   background-color: #6bc072;
#   color: #000000;
# }
# #T_55212_row10_col0 {
#   background-color: #e2f4dd;
#   color: #000000;
# }
# #T_55212_row10_col1 {
#   background-color: #cdecc7;
#   color: #000000;
# }
# #T_55212_row11_col0 {
#   background-color: #46ae60;
#   color: #f1f1f1;
# }
# #T_55212_row12_col1 {
#   background-color: #81ca81;
#   color: #000000;
# }
# #T_55212_row13_col0, #T_55212_row15_col1 {
#   background-color: lightgreen;
#   background-color: lightgreen;
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_55212_row13_col1 {
#   background-color: #147e3a;
#   color: #f1f1f1;
# }
# #T_55212_row14_col0 {
#   background-color: #cbebc5;
#   color: #000000;
# }
# #T_55212_row15_col0 {
#   background-color: #7fc97f;
#   color: #000000;
# }
# #T_55212_row16_col0 {
#   background-color: #f3faf0;
#   color: #000000;
# }
# </style>
# <table id="T_55212" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_55212_level0_col0" class="col_heading level0 col0" >ventas</th>
#       <th id="T_55212_level0_col1" class="col_heading level0 col1" >ganancia</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Tipo de Producto</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_55212_level0_row0" class="row_heading level0 row0" >Brotes</th>
#       <td id="T_55212_row0_col0" class="data row0 col0" >USD 8,811.32</td>
#       <td id="T_55212_row0_col1" class="data row0 col1" >USD 1,381.42</td>
#     </tr>
#     <tr>
#       <th id="T_55212_level0_row1" class="row_heading level0 row1" >Decoración de jardín</th>
#       <td id="T_55212_row1_col0" class="data row1 col0" >USD 82,680.08</td>
#       <td id="T_55212_row1_col1" class="data row1 col1" >USD 9,939.43</td>
#     </tr>
#     <tr>
#       <th id="T_55212_level0_row2" class="row_heading level0 row2" >Equipos de limpieza</th>
#       <td id="T_55212_row2_col0" class="data row2 col0" >USD 542,304.58</td>
#       <td id="T_55212_row2_col1" class="data row2 col1" >USD 8,724.39</td>
#     </tr>
#     <tr>
#       <th id="T_55212_level0_row3" class="row_heading level0 row3" >Fertilizantes</th>
#       <td id="T_55212_row3_col0" class="data row3 col0" >USD 53,144.74</td>
#       <td id="T_55212_row3_col1" class="data row3 col1" >USD 11,254.88</td>
#     </tr>
#     <tr>
#       <th id="T_55212_level0_row4" class="row_heading level0 row4" >Fontanería</th>
#       <td id="T_55212_row4_col0" class="data row4 col0" >USD 373,223.88</td>
#       <td id="T_55212_row4_col1" class="data row4 col1" >USD -5,622.34</td>
#     </tr>
#     <tr>
#       <th id="T_55212_level0_row5" class="row_heading level0 row5" >Herramientas</th>
#       <td id="T_55212_row5_col0" class="data row5 col0" >USD 995,158.41</td>
#       <td id="T_55212_row5_col1" class="data row5 col1" >USD 41,020.34</td>
#     </tr>
#     <tr>
#       <th id="T_55212_level0_row6" class="row_heading level0 row6" >Herramientas automotrices</th>
#       <td id="T_55212_row6_col0" class="data row6 col0" >USD 502,109.29</td>
#       <td id="T_55212_row6_col1" class="data row6 col1" >USD 63,330.22</td>
#     </tr>
#     <tr>
#       <th id="T_55212_level0_row7" class="row_heading level0 row7" >Herramientas de jardinería</th>
#       <td id="T_55212_row7_col0" class="data row7 col0" >USD 648,879.72</td>
#       <td id="T_55212_row7_col1" class="data row7 col1" >USD 53,202.88</td>
#     </tr>
#     <tr>
#       <th id="T_55212_level0_row8" class="row_heading level0 row8" >Iluminación</th>
#       <td id="T_55212_row8_col0" class="data row8 col0" >USD 275,229.53</td>
#       <td id="T_55212_row8_col1" class="data row8 col1" >USD 20,264.54</td>
#     </tr>
#     <tr>
#       <th id="T_55212_level0_row9" class="row_heading level0 row9" >Macetas</th>
#       <td id="T_55212_row9_col0" class="data row9 col0" >USD 696,044.18</td>
#       <td id="T_55212_row9_col1" class="data row9 col1" >USD 33,941.85</td>
#     </tr>
#     <tr>
#       <th id="T_55212_level0_row10" class="row_heading level0 row10" >Materiales de paisajismo</th>
#       <td id="T_55212_row10_col0" class="data row10 col0" >USD 150,552.49</td>
#       <td id="T_55212_row10_col1" class="data row10 col1" >USD -1,912.37</td>
#     </tr>
#     <tr>
#       <th id="T_55212_level0_row11" class="row_heading level0 row11" >Materiales de revestimiento</th>
#       <td id="T_55212_row11_col0" class="data row11 col0" >USD 629,656.36</td>
#       <td id="T_55212_row11_col1" class="data row11 col1" >USD -28,869.01</td>
#     </tr>
#     <tr>
#       <th id="T_55212_level0_row12" class="row_heading level0 row12" >Muebles de exterior</th>
#       <td id="T_55212_row12_col0" class="data row12 col0" >USD 328,932.27</td>
#       <td id="T_55212_row12_col1" class="data row12 col1" >USD 26,784.59</td>
#     </tr>
#     <tr>
#       <th id="T_55212_level0_row13" class="row_heading level0 row13" >Neumáticos</th>
#       <td id="T_55212_row13_col0" class="data row13 col0" >USD 1,022,428.97</td>
#       <td id="T_55212_row13_col1" class="data row13 col1" >USD 67,460.05</td>
#     </tr>
#     <tr>
#       <th id="T_55212_level0_row14" class="row_heading level0 row14" >Pesticidas</th>
#       <td id="T_55212_row14_col0" class="data row14 col0" >USD 244,956.04</td>
#       <td id="T_55212_row14_col1" class="data row14 col1" >USD 53,343.89</td>
#     </tr>
#     <tr>
#       <th id="T_55212_level0_row15" class="row_heading level0 row15" >Piezas de repuesto</th>
#       <td id="T_55212_row15_col0" class="data row15 col0" >USD 486,907.94</td>
#       <td id="T_55212_row15_col1" class="data row15 col1" >USD 91,148.67</td>
#     </tr>
#     <tr>
#       <th id="T_55212_level0_row16" class="row_heading level0 row16" >Semillas</th>
#       <td id="T_55212_row16_col0" class="data row16 col0" >USD 39,979.75</td>
#       <td id="T_55212_row16_col1" class="data row16 col1" >USD 8,865.09</td>
#     </tr>
#   </tbody>
# </table>

# %%
encabezado = {
              'selector':'th',
              'props':'font-weight: bold; font-family: Arial; text-align: center; text-transform: capitalize'
}

# %%
estilo_producto.set_table_styles([encabezado], overwrite=False)
estilo_producto
# Out:
# <style type="text/css">
# #T_55212 th {
#   font-weight: bold;
#   font-family: Arial;
#   text-align: center;
#   text-transform: capitalize;
# }
# #T_55212_row0_col0, #T_55212_row11_col1 {
#   background-color: red;
#   background-color: lightred;
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_55212_row0_col1 {
#   background-color: #c7e9c0;
#   color: #000000;
# }
# #T_55212_row1_col0 {
#   background-color: #edf8e9;
#   color: #000000;
# }
# #T_55212_row1_col1 {
#   background-color: #b1e0ab;
#   color: #000000;
# }
# #T_55212_row2_col0 {
#   background-color: #6abf71;
#   color: #000000;
# }
# #T_55212_row2_col1, #T_55212_row12_col0, #T_55212_row16_col1 {
#   background-color: #b4e1ad;
#   color: #000000;
# }
# #T_55212_row3_col0 {
#   background-color: #f1faee;
#   color: #000000;
# }
# #T_55212_row3_col1 {
#   background-color: #aedea7;
#   color: #000000;
# }
# #T_55212_row4_col0 {
#   background-color: #a5db9f;
#   color: #000000;
# }
# #T_55212_row4_col1 {
#   background-color: #d5efcf;
#   color: #000000;
# }
# #T_55212_row5_col0 {
#   background-color: #004c1e;
#   color: #f1f1f1;
# }
# #T_55212_row5_col1 {
#   background-color: #52b365;
#   color: #f1f1f1;
# }
# #T_55212_row6_col0 {
#   background-color: #79c67a;
#   color: #000000;
# }
# #T_55212_row6_col1 {
#   background-color: #1e8741;
#   color: #f1f1f1;
# }
# #T_55212_row7_col0 {
#   background-color: #3fa95c;
#   color: #f1f1f1;
# }
# #T_55212_row7_col1, #T_55212_row14_col1 {
#   background-color: #329b51;
#   color: #f1f1f1;
# }
# #T_55212_row8_col0 {
#   background-color: #c3e7bc;
#   color: #000000;
# }
# #T_55212_row8_col1 {
#   background-color: #95d391;
#   color: #000000;
# }
# #T_55212_row9_col0 {
#   background-color: #349d53;
#   color: #f1f1f1;
# }
# #T_55212_row9_col1 {
#   background-color: #6bc072;
#   color: #000000;
# }
# #T_55212_row10_col0 {
#   background-color: #e2f4dd;
#   color: #000000;
# }
# #T_55212_row10_col1 {
#   background-color: #cdecc7;
#   color: #000000;
# }
# #T_55212_row11_col0 {
#   background-color: #46ae60;
#   color: #f1f1f1;
# }
# #T_55212_row12_col1 {
#   background-color: #81ca81;
#   color: #000000;
# }
# #T_55212_row13_col0, #T_55212_row15_col1 {
#   background-color: lightgreen;
#   background-color: lightgreen;
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_55212_row13_col1 {
#   background-color: #147e3a;
#   color: #f1f1f1;
# }
# #T_55212_row14_col0 {
#   background-color: #cbebc5;
#   color: #000000;
# }
# #T_55212_row15_col0 {
#   background-color: #7fc97f;
#   color: #000000;
# }
# #T_55212_row16_col0 {
#   background-color: #f3faf0;
#   color: #000000;
# }
# </style>
# <table id="T_55212" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_55212_level0_col0" class="col_heading level0 col0" >ventas</th>
#       <th id="T_55212_level0_col1" class="col_heading level0 col1" >ganancia</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Tipo de Producto</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_55212_level0_row0" class="row_heading level0 row0" >Brotes</th>
#       <td id="T_55212_row0_col0" class="data row0 col0" >USD 8,811.32</td>
#       <td id="T_55212_row0_col1" class="data row0 col1" >USD 1,381.42</td>
#     </tr>
#     <tr>
#       <th id="T_55212_level0_row1" class="row_heading level0 row1" >Decoración de jardín</th>
#       <td id="T_55212_row1_col0" class="data row1 col0" >USD 82,680.08</td>
#       <td id="T_55212_row1_col1" class="data row1 col1" >USD 9,939.43</td>
#     </tr>
#     <tr>
#       <th id="T_55212_level0_row2" class="row_heading level0 row2" >Equipos de limpieza</th>
#       <td id="T_55212_row2_col0" class="data row2 col0" >USD 542,304.58</td>
#       <td id="T_55212_row2_col1" class="data row2 col1" >USD 8,724.39</td>
#     </tr>
#     <tr>
#       <th id="T_55212_level0_row3" class="row_heading level0 row3" >Fertilizantes</th>
#       <td id="T_55212_row3_col0" class="data row3 col0" >USD 53,144.74</td>
#       <td id="T_55212_row3_col1" class="data row3 col1" >USD 11,254.88</td>
#     </tr>
#     <tr>
#       <th id="T_55212_level0_row4" class="row_heading level0 row4" >Fontanería</th>
#       <td id="T_55212_row4_col0" class="data row4 col0" >USD 373,223.88</td>
#       <td id="T_55212_row4_col1" class="data row4 col1" >USD -5,622.34</td>
#     </tr>
#     <tr>
#       <th id="T_55212_level0_row5" class="row_heading level0 row5" >Herramientas</th>
#       <td id="T_55212_row5_col0" class="data row5 col0" >USD 995,158.41</td>
#       <td id="T_55212_row5_col1" class="data row5 col1" >USD 41,020.34</td>
#     </tr>
#     <tr>
#       <th id="T_55212_level0_row6" class="row_heading level0 row6" >Herramientas automotrices</th>
#       <td id="T_55212_row6_col0" class="data row6 col0" >USD 502,109.29</td>
#       <td id="T_55212_row6_col1" class="data row6 col1" >USD 63,330.22</td>
#     </tr>
#     <tr>
#       <th id="T_55212_level0_row7" class="row_heading level0 row7" >Herramientas de jardinería</th>
#       <td id="T_55212_row7_col0" class="data row7 col0" >USD 648,879.72</td>
#       <td id="T_55212_row7_col1" class="data row7 col1" >USD 53,202.88</td>
#     </tr>
#     <tr>
#       <th id="T_55212_level0_row8" class="row_heading level0 row8" >Iluminación</th>
#       <td id="T_55212_row8_col0" class="data row8 col0" >USD 275,229.53</td>
#       <td id="T_55212_row8_col1" class="data row8 col1" >USD 20,264.54</td>
#     </tr>
#     <tr>
#       <th id="T_55212_level0_row9" class="row_heading level0 row9" >Macetas</th>
#       <td id="T_55212_row9_col0" class="data row9 col0" >USD 696,044.18</td>
#       <td id="T_55212_row9_col1" class="data row9 col1" >USD 33,941.85</td>
#     </tr>
#     <tr>
#       <th id="T_55212_level0_row10" class="row_heading level0 row10" >Materiales de paisajismo</th>
#       <td id="T_55212_row10_col0" class="data row10 col0" >USD 150,552.49</td>
#       <td id="T_55212_row10_col1" class="data row10 col1" >USD -1,912.37</td>
#     </tr>
#     <tr>
#       <th id="T_55212_level0_row11" class="row_heading level0 row11" >Materiales de revestimiento</th>
#       <td id="T_55212_row11_col0" class="data row11 col0" >USD 629,656.36</td>
#       <td id="T_55212_row11_col1" class="data row11 col1" >USD -28,869.01</td>
#     </tr>
#     <tr>
#       <th id="T_55212_level0_row12" class="row_heading level0 row12" >Muebles de exterior</th>
#       <td id="T_55212_row12_col0" class="data row12 col0" >USD 328,932.27</td>
#       <td id="T_55212_row12_col1" class="data row12 col1" >USD 26,784.59</td>
#     </tr>
#     <tr>
#       <th id="T_55212_level0_row13" class="row_heading level0 row13" >Neumáticos</th>
#       <td id="T_55212_row13_col0" class="data row13 col0" >USD 1,022,428.97</td>
#       <td id="T_55212_row13_col1" class="data row13 col1" >USD 67,460.05</td>
#     </tr>
#     <tr>
#       <th id="T_55212_level0_row14" class="row_heading level0 row14" >Pesticidas</th>
#       <td id="T_55212_row14_col0" class="data row14 col0" >USD 244,956.04</td>
#       <td id="T_55212_row14_col1" class="data row14 col1" >USD 53,343.89</td>
#     </tr>
#     <tr>
#       <th id="T_55212_level0_row15" class="row_heading level0 row15" >Piezas de repuesto</th>
#       <td id="T_55212_row15_col0" class="data row15 col0" >USD 486,907.94</td>
#       <td id="T_55212_row15_col1" class="data row15 col1" >USD 91,148.67</td>
#     </tr>
#     <tr>
#       <th id="T_55212_level0_row16" class="row_heading level0 row16" >Semillas</th>
#       <td id="T_55212_row16_col0" class="data row16 col0" >USD 39,979.75</td>
#       <td id="T_55212_row16_col1" class="data row16 col1" >USD 8,865.09</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Misión 3: Equipo de Logística
#
# Necesitamos construir una visualización que nos permita entender la **distribución de pedidos por región de Brasil**.
#
# Así, el equipo de logística va a saber dónde hay más oportunidad de enfocar los esfuerzos de material y mano de obra.

# %%
region = pd.DataFrame(ventas["region"].value_counts())
region.columns = ["# Pedidos"]
region.index.name = "Region"
region
# Out:
#               # Pedidos
# Region
# Buenos Aires       2822
# Litoral            1924
# Norte              1555
# Central            1276
# Cuyo                915
# Patagónica          448

# %%
import numpy as np

# %%
porcentaje = region['# Pedidos'].to_numpy()
porcentaje = 100*porcentaje/porcentaje.sum()
porcentaje
# Out:
# array([31.56599553, 21.5212528 , 17.39373602, 14.27293065, 10.23489933,
#         5.01118568])

# %%
region["Porcentaje de pedidos"] = porcentaje
region
# Out:
#               # Pedidos  Porcentaje de pedidos
# Region
# Buenos Aires       2822              31.565996
# Litoral            1924              21.521253
# Norte              1555              17.393736
# Central            1276              14.272931
# Cuyo                915              10.234899
# Patagónica          448               5.011186

# %%
estilo_region = region.style

# %%
encabezado = {
              'selector':'th',
              'props':'font-weight: bold; font-family: Arial; text-align: center; background-color: white'
}

celdas = {
              'selector':'td',
              'props':'background-color: white'
}

estilo_region.set_table_styles([encabezado, celdas])
estilo_region
# Out:
# <style type="text/css">
# #T_5789f th {
#   font-weight: bold;
#   font-family: Arial;
#   text-align: center;
#   background-color: white;
# }
# #T_5789f td {
#   background-color: white;
# }
# </style>
# <table id="T_5789f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5789f_level0_col0" class="col_heading level0 col0" ># Pedidos</th>
#       <th id="T_5789f_level0_col1" class="col_heading level0 col1" >Porcentaje de pedidos</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Region</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5789f_level0_row0" class="row_heading level0 row0" >Buenos Aires</th>
#       <td id="T_5789f_row0_col0" class="data row0 col0" >2822</td>
#       <td id="T_5789f_row0_col1" class="data row0 col1" >31.565996</td>
#     </tr>
#     <tr>
#       <th id="T_5789f_level0_row1" class="row_heading level0 row1" >Litoral</th>
#       <td id="T_5789f_row1_col0" class="data row1 col0" >1924</td>
#       <td id="T_5789f_row1_col1" class="data row1 col1" >21.521253</td>
#     </tr>
#     <tr>
#       <th id="T_5789f_level0_row2" class="row_heading level0 row2" >Norte</th>
#       <td id="T_5789f_row2_col0" class="data row2 col0" >1555</td>
#       <td id="T_5789f_row2_col1" class="data row2 col1" >17.393736</td>
#     </tr>
#     <tr>
#       <th id="T_5789f_level0_row3" class="row_heading level0 row3" >Central</th>
#       <td id="T_5789f_row3_col0" class="data row3 col0" >1276</td>
#       <td id="T_5789f_row3_col1" class="data row3 col1" >14.272931</td>
#     </tr>
#     <tr>
#       <th id="T_5789f_level0_row4" class="row_heading level0 row4" >Cuyo</th>
#       <td id="T_5789f_row4_col0" class="data row4 col0" >915</td>
#       <td id="T_5789f_row4_col1" class="data row4 col1" >10.234899</td>
#     </tr>
#     <tr>
#       <th id="T_5789f_level0_row5" class="row_heading level0 row5" >Patagónica</th>
#       <td id="T_5789f_row5_col0" class="data row5 col0" >448</td>
#       <td id="T_5789f_row5_col1" class="data row5 col1" >5.011186</td>
#     </tr>
#   </tbody>
# </table>

# %%
estilo_region.format({"Porcentaje de pedidos":"{:.2f}%"}).bar(subset=["Porcentaje de pedidos"], vmin = 0, vmax = 100, color="#9cd3bb")
# Out:
# <style type="text/css">
# #T_5789f th {
#   font-weight: bold;
#   font-family: Arial;
#   text-align: center;
#   background-color: white;
# }
# #T_5789f td {
#   background-color: white;
# }
# #T_5789f_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #9cd3bb 31.6%, transparent 31.6%);
#   width: 10em;
#   background: linear-gradient(90deg, #9cd3bb 31.6%, transparent 31.6%);
# }
# #T_5789f_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #9cd3bb 21.5%, transparent 21.5%);
#   width: 10em;
#   background: linear-gradient(90deg, #9cd3bb 21.5%, transparent 21.5%);
# }
# #T_5789f_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #9cd3bb 17.4%, transparent 17.4%);
#   width: 10em;
#   background: linear-gradient(90deg, #9cd3bb 17.4%, transparent 17.4%);
# }
# #T_5789f_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #9cd3bb 14.3%, transparent 14.3%);
#   width: 10em;
#   background: linear-gradient(90deg, #9cd3bb 14.3%, transparent 14.3%);
# }
# #T_5789f_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #9cd3bb 10.2%, transparent 10.2%);
#   width: 10em;
#   background: linear-gradient(90deg, #9cd3bb 10.2%, transparent 10.2%);
# }
# #T_5789f_row5_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #9cd3bb 5.0%, transparent 5.0%);
#   width: 10em;
#   background: linear-gradient(90deg, #9cd3bb 5.0%, transparent 5.0%);
# }
# </style>
# <table id="T_5789f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5789f_level0_col0" class="col_heading level0 col0" ># Pedidos</th>
#       <th id="T_5789f_level0_col1" class="col_heading level0 col1" >Porcentaje de pedidos</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Region</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5789f_level0_row0" class="row_heading level0 row0" >Buenos Aires</th>
#       <td id="T_5789f_row0_col0" class="data row0 col0" >2822</td>
#       <td id="T_5789f_row0_col1" class="data row0 col1" >31.57%</td>
#     </tr>
#     <tr>
#       <th id="T_5789f_level0_row1" class="row_heading level0 row1" >Litoral</th>
#       <td id="T_5789f_row1_col0" class="data row1 col0" >1924</td>
#       <td id="T_5789f_row1_col1" class="data row1 col1" >21.52%</td>
#     </tr>
#     <tr>
#       <th id="T_5789f_level0_row2" class="row_heading level0 row2" >Norte</th>
#       <td id="T_5789f_row2_col0" class="data row2 col0" >1555</td>
#       <td id="T_5789f_row2_col1" class="data row2 col1" >17.39%</td>
#     </tr>
#     <tr>
#       <th id="T_5789f_level0_row3" class="row_heading level0 row3" >Central</th>
#       <td id="T_5789f_row3_col0" class="data row3 col0" >1276</td>
#       <td id="T_5789f_row3_col1" class="data row3 col1" >14.27%</td>
#     </tr>
#     <tr>
#       <th id="T_5789f_level0_row4" class="row_heading level0 row4" >Cuyo</th>
#       <td id="T_5789f_row4_col0" class="data row4 col0" >915</td>
#       <td id="T_5789f_row4_col1" class="data row4 col1" >10.23%</td>
#     </tr>
#     <tr>
#       <th id="T_5789f_level0_row5" class="row_heading level0 row5" >Patagónica</th>
#       <td id="T_5789f_row5_col0" class="data row5 col0" >448</td>
#       <td id="T_5789f_row5_col1" class="data row5 col1" >5.01%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Misión 4: Equipo de Logística
#
# Nuevamente el equipo de logística desea replantear su estructura y organización de provisionamiento de productos e, para ello, se pensó en una visualización que permita identificar el estándar de la **cantidad de productos solicitados por mes por departamento**.

# %%
meses = ventas.copy()
meses = meses.sort_values(by="fecha_pedido")
meses
# Out:
#      fecha_pedido        modo_envio      nombre_cliente segmento_cliente  \
# 7171   2016-01-04  Entrega estándar       Ramiro Guzmán              B2C
# 651    2016-01-05  Entrega estándar     Jerónimo Cortés              B2B
# 650    2016-01-05  Entrega estándar     Jerónimo Cortés              B2B
# 649    2016-01-05  Entrega estándar     Jerónimo Cortés              B2B
# 1576   2016-01-06  Entrega estándar    Florencia Chávez              B2C
# ...           ...               ...                 ...              ...
# 796    2019-12-31  Entrega estándar      Olivia Aguilar              B2C
# 795    2019-12-31  Entrega estándar      Olivia Aguilar              B2C
# 794    2019-12-31  Entrega estándar      Olivia Aguilar              B2C
# 1151   2019-12-31  Entrega estándar  Francisco Cárdenas              B2B
# 1152   2019-12-31  Entrega estándar  Francisco Cárdenas              B2B
#
#                                ciudad                        provincia  \
# 7171                          Rosario                         Santa Fe
# 651                         Pergamino                     Buenos Aires
# 650                         Pergamino                     Buenos Aires
# 649                         Pergamino                     Buenos Aires
# 1576  Ciudad Autónoma de Buenos Aires  Ciudad Autónoma de Buenos Aires
# ...                               ...                              ...
# 796                          La Plata                     Buenos Aires
# 795                          La Plata                     Buenos Aires
# 794                          La Plata                     Buenos Aires
# 1151                          Quilmes                     Buenos Aires
# 1152                          Quilmes                     Buenos Aires
#
#             region                departamento               tipo_producto  \
# 7171       Litoral     Jardinería y paisajismo                  Pesticidas
# 651   Buenos Aires     Jardinería y paisajismo  Herramientas de jardinería
# 650   Buenos Aires     Jardinería y paisajismo                     Macetas
# 649   Buenos Aires     Jardinería y paisajismo                    Semillas
# 1576  Buenos Aires     Jardinería y paisajismo        Decoración de jardín
# ...            ...                         ...                         ...
# 796   Buenos Aires     Jardinería y paisajismo  Herramientas de jardinería
# 795   Buenos Aires                  Automotriz                  Neumáticos
# 794   Buenos Aires  Materiales de construcción                  Fontanería
# 1151  Buenos Aires     Jardinería y paisajismo  Herramientas de jardinería
# 1152  Buenos Aires     Jardinería y paisajismo  Herramientas de jardinería
#
#        ventas  cantidad  ganancia
# 7171    55.92         2      9.44
# 651     12.04         2     -9.32
# 650    927.30         3   -110.13
# 649     40.08         3      7.26
# 1576    66.42         3      8.31
# ...       ...       ...       ...
# 796    179.43         3     33.63
# 795    309.19         7      4.69
# 794   1098.68         4     20.60
# 1151    47.28         2      7.68
# 1152    70.44         2     11.00
#
# [8940 rows x 12 columns]

# %%
meses["mes"] = meses["fecha_pedido"].dt.strftime("%Y - %b")
meses = meses.reset_index(drop=True)
meses
# Out:
#      fecha_pedido        modo_envio      nombre_cliente segmento_cliente  \
# 0      2016-01-04  Entrega estándar       Ramiro Guzmán              B2C
# 1      2016-01-05  Entrega estándar     Jerónimo Cortés              B2B
# 2      2016-01-05  Entrega estándar     Jerónimo Cortés              B2B
# 3      2016-01-05  Entrega estándar     Jerónimo Cortés              B2B
# 4      2016-01-06  Entrega estándar    Florencia Chávez              B2C
# ...           ...               ...                 ...              ...
# 8935   2019-12-31  Entrega estándar      Olivia Aguilar              B2C
# 8936   2019-12-31  Entrega estándar      Olivia Aguilar              B2C
# 8937   2019-12-31  Entrega estándar      Olivia Aguilar              B2C
# 8938   2019-12-31  Entrega estándar  Francisco Cárdenas              B2B
# 8939   2019-12-31  Entrega estándar  Francisco Cárdenas              B2B
#
#                                ciudad                        provincia  \
# 0                             Rosario                         Santa Fe
# 1                           Pergamino                     Buenos Aires
# 2                           Pergamino                     Buenos Aires
# 3                           Pergamino                     Buenos Aires
# 4     Ciudad Autónoma de Buenos Aires  Ciudad Autónoma de Buenos Aires
# ...                               ...                              ...
# 8935                         La Plata                     Buenos Aires
# 8936                         La Plata                     Buenos Aires
# 8937                         La Plata                     Buenos Aires
# 8938                          Quilmes                     Buenos Aires
# 8939                          Quilmes                     Buenos Aires
#
#             region                departamento               tipo_producto  \
# 0          Litoral     Jardinería y paisajismo                  Pesticidas
# 1     Buenos Aires     Jardinería y paisajismo  Herramientas de jardinería
# 2     Buenos Aires     Jardinería y paisajismo                     Macetas
# 3     Buenos Aires     Jardinería y paisajismo                    Semillas
# 4     Buenos Aires     Jardinería y paisajismo        Decoración de jardín
# ...            ...                         ...                         ...
# 8935  Buenos Aires     Jardinería y paisajismo  Herramientas de jardinería
# 8936  Buenos Aires                  Automotriz                  Neumáticos
# 8937  Buenos Aires  Materiales de construcción                  Fontanería
# 8938  Buenos Aires     Jardinería y paisajismo  Herramientas de jardinería
# 8939  Buenos Aires     Jardinería y paisajismo  Herramientas de jardinería
#
#        ventas  cantidad  ganancia         mes
# 0       55.92         2      9.44  2016 - Jan
# 1       12.04         2     -9.32  2016 - Jan
# 2      927.30         3   -110.13  2016 - Jan
# 3       40.08         3      7.26  2016 - Jan
# 4       66.42         3      8.31  2016 - Jan
# ...       ...       ...       ...         ...
# 8935   179.43         3     33.63  2019 - Dec
# 8936   309.19         7      4.69  2019 - Dec
# 8937  1098.68         4     20.60  2019 - Dec
# 8938    47.28         2      7.68  2019 - Dec
# 8939    70.44         2     11.00  2019 - Dec
#
# [8940 rows x 13 columns]

# %%
pd.set_option("display.max_columns", None)

# %%
ventas_mensuales = meses.pivot_table(index=meses.departamento, columns="mes", values="cantidad", aggfunc="sum", sort = False)
ventas_mensuales
# Out:
# mes                         2016 - Jan  2016 - Feb  2016 - Mar  2016 - Apr  \
# departamento
# Jardinería y paisajismo            161          87         277         323
# Automotriz                          45          20          46         107
# Materiales de construcción          60          23         102          69
#
# mes                         2016 - May  2016 - Jun  2016 - Jul  2016 - Aug  \
# departamento
# Jardinería y paisajismo            270         273         348         339
# Automotriz                          81          83          91          95
# Materiales de construcción          91         114         104         101
#
# mes                         2016 - Sep  2016 - Oct  2016 - Nov  2016 - Dec  \
# departamento
# Jardinería y paisajismo            549         276         716         525
# Automotriz                         154          85         236         154
# Materiales de construcción         182          94         213         269
#
# mes                         2017 - Jan  2017 - Feb  2017 - Mar  2017 - Apr  \
# departamento
# Jardinería y paisajismo             97         131         278         271
# Automotriz                          55          44          74         111
# Materiales de construcción          93          38         100          85
#
# mes                         2017 - May  2017 - Jun  2017 - Jul  2017 - Aug  \
# departamento
# Jardinería y paisajismo            269         321         268         322
# Automotriz                          94          59          88         117
# Materiales de construcción          76         120         128         106
#
# mes                         2017 - Sep  2017 - Oct  2017 - Nov  2017 - Dec  \
# departamento
# Jardinería y paisajismo            663         260         746         628
# Automotriz                         180         100         179         235
# Materiales de construcción         194         129         259         258
#
# mes                         2018 - Jan  2018 - Feb  2018 - Mar  2018 - Apr  \
# departamento
# Jardinería y paisajismo            190         177         260         338
# Automotriz                          59          49         112          72
# Materiales de construcción          91          67         127         128
#
# mes                         2018 - May  2018 - Jun  2018 - Jul  2018 - Aug  \
# departamento
# Jardinería y paisajismo            463         473         413         380
# Automotriz                         124         118         117         123
# Materiales de construcción         171         117         132         113
#
# mes                         2018 - Sep  2018 - Oct  2018 - Nov  2018 - Dec  \
# departamento
# Jardinería y paisajismo            757         402         727         770
# Automotriz                         181         103         253         189
# Materiales de construcción         227         171         308         294
#
# mes                         2019 - Jan  2019 - Feb  2019 - Mar  2019 - Apr  \
# departamento
# Jardinería y paisajismo            361         205         458         415
# Automotriz                         109          63         167          87
# Materiales de construcción          83          67         107         131
#
# mes                         2019 - May  2019 - Jun  2019 - Jul  2019 - Aug  \
# departamento
# Jardinería y paisajismo            542         490         423         561
# Automotriz                         150         170         168         136
# Materiales de construcción         172         151         162         132
#
# mes                         2019 - Sep  2019 - Oct  2019 - Nov  2019 - Dec
# departamento
# Jardinería y paisajismo            929         617         946         989
# Automotriz                         280         205         331         252
# Materiales de construcción         282         213         312         395

# %%
estilo_mensual = ventas_mensuales.style

# %%
estilo_mensual.set_sticky(axis="index")
estilo_mensual
# Out:
# <style type="text/css">
# #T_9777f .col_heading {
#   font-weight: normal;
#   font-family: Arial;
# }
# #T_9777f td {
#   text-align: center;
# }
# #T_9777f th {
#   text-align: center;
# }
# #T_9777f .index_name {
#   font-weight: bold;
#   font-family: Arial;
#   text-align: right;
# }
# #T_9777f .col_heading {
#   font-weight: normal;
#   font-family: Arial;
# }
# #T_9777f td {
#   text-align: center;
# }
# #T_9777f th {
#   text-align: center;
# }
# #T_9777f .index_name {
#   font-weight: bold;
#   font-family: Arial;
#   text-align: right;
# }
# #T_9777f thead tr th:nth-child(1) {
#   position: sticky;
#   background-color: inherit;
#   left: 0px;
#   z-index: 3 !important;
# }
# #T_9777f tbody tr th:nth-child(1) {
#   position: sticky;
#   background-color: inherit;
#   left: 0px;
#   z-index: 1;
# }
# </style>
# <table id="T_9777f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >mes</th>
#       <th id="T_9777f_level0_col0" class="col_heading level0 col0" >2016 - Jan</th>
#       <th id="T_9777f_level0_col1" class="col_heading level0 col1" >2016 - Feb</th>
#       <th id="T_9777f_level0_col2" class="col_heading level0 col2" >2016 - Mar</th>
#       <th id="T_9777f_level0_col3" class="col_heading level0 col3" >2016 - Apr</th>
#       <th id="T_9777f_level0_col4" class="col_heading level0 col4" >2016 - May</th>
#       <th id="T_9777f_level0_col5" class="col_heading level0 col5" >2016 - Jun</th>
#       <th id="T_9777f_level0_col6" class="col_heading level0 col6" >2016 - Jul</th>
#       <th id="T_9777f_level0_col7" class="col_heading level0 col7" >2016 - Aug</th>
#       <th id="T_9777f_level0_col8" class="col_heading level0 col8" >2016 - Sep</th>
#       <th id="T_9777f_level0_col9" class="col_heading level0 col9" >2016 - Oct</th>
#       <th id="T_9777f_level0_col10" class="col_heading level0 col10" >2016 - Nov</th>
#       <th id="T_9777f_level0_col11" class="col_heading level0 col11" >2016 - Dec</th>
#       <th id="T_9777f_level0_col12" class="col_heading level0 col12" >2017 - Jan</th>
#       <th id="T_9777f_level0_col13" class="col_heading level0 col13" >2017 - Feb</th>
#       <th id="T_9777f_level0_col14" class="col_heading level0 col14" >2017 - Mar</th>
#       <th id="T_9777f_level0_col15" class="col_heading level0 col15" >2017 - Apr</th>
#       <th id="T_9777f_level0_col16" class="col_heading level0 col16" >2017 - May</th>
#       <th id="T_9777f_level0_col17" class="col_heading level0 col17" >2017 - Jun</th>
#       <th id="T_9777f_level0_col18" class="col_heading level0 col18" >2017 - Jul</th>
#       <th id="T_9777f_level0_col19" class="col_heading level0 col19" >2017 - Aug</th>
#       <th id="T_9777f_level0_col20" class="col_heading level0 col20" >2017 - Sep</th>
#       <th id="T_9777f_level0_col21" class="col_heading level0 col21" >2017 - Oct</th>
#       <th id="T_9777f_level0_col22" class="col_heading level0 col22" >2017 - Nov</th>
#       <th id="T_9777f_level0_col23" class="col_heading level0 col23" >2017 - Dec</th>
#       <th id="T_9777f_level0_col24" class="col_heading level0 col24" >2018 - Jan</th>
#       <th id="T_9777f_level0_col25" class="col_heading level0 col25" >2018 - Feb</th>
#       <th id="T_9777f_level0_col26" class="col_heading level0 col26" >2018 - Mar</th>
#       <th id="T_9777f_level0_col27" class="col_heading level0 col27" >2018 - Apr</th>
#       <th id="T_9777f_level0_col28" class="col_heading level0 col28" >2018 - May</th>
#       <th id="T_9777f_level0_col29" class="col_heading level0 col29" >2018 - Jun</th>
#       <th id="T_9777f_level0_col30" class="col_heading level0 col30" >2018 - Jul</th>
#       <th id="T_9777f_level0_col31" class="col_heading level0 col31" >2018 - Aug</th>
#       <th id="T_9777f_level0_col32" class="col_heading level0 col32" >2018 - Sep</th>
#       <th id="T_9777f_level0_col33" class="col_heading level0 col33" >2018 - Oct</th>
#       <th id="T_9777f_level0_col34" class="col_heading level0 col34" >2018 - Nov</th>
#       <th id="T_9777f_level0_col35" class="col_heading level0 col35" >2018 - Dec</th>
#       <th id="T_9777f_level0_col36" class="col_heading level0 col36" >2019 - Jan</th>
#       <th id="T_9777f_level0_col37" class="col_heading level0 col37" >2019 - Feb</th>
#       <th id="T_9777f_level0_col38" class="col_heading level0 col38" >2019 - Mar</th>
#       <th id="T_9777f_level0_col39" class="col_heading level0 col39" >2019 - Apr</th>
#       <th id="T_9777f_level0_col40" class="col_heading level0 col40" >2019 - May</th>
#       <th id="T_9777f_level0_col41" class="col_heading level0 col41" >2019 - Jun</th>
#       <th id="T_9777f_level0_col42" class="col_heading level0 col42" >2019 - Jul</th>
#       <th id="T_9777f_level0_col43" class="col_heading level0 col43" >2019 - Aug</th>
#       <th id="T_9777f_level0_col44" class="col_heading level0 col44" >2019 - Sep</th>
#       <th id="T_9777f_level0_col45" class="col_heading level0 col45" >2019 - Oct</th>
#       <th id="T_9777f_level0_col46" class="col_heading level0 col46" >2019 - Nov</th>
#       <th id="T_9777f_level0_col47" class="col_heading level0 col47" >2019 - Dec</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >departamento</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#       <th class="blank col18" >&nbsp;</th>
#       <th class="blank col19" >&nbsp;</th>
#       <th class="blank col20" >&nbsp;</th>
#       <th class="blank col21" >&nbsp;</th>
#       <th class="blank col22" >&nbsp;</th>
#       <th class="blank col23" >&nbsp;</th>
#       <th class="blank col24" >&nbsp;</th>
#       <th class="blank col25" >&nbsp;</th>
#       <th class="blank col26" >&nbsp;</th>
#       <th class="blank col27" >&nbsp;</th>
#       <th class="blank col28" >&nbsp;</th>
#       <th class="blank col29" >&nbsp;</th>
#       <th class="blank col30" >&nbsp;</th>
#       <th class="blank col31" >&nbsp;</th>
#       <th class="blank col32" >&nbsp;</th>
#       <th class="blank col33" >&nbsp;</th>
#       <th class="blank col34" >&nbsp;</th>
#       <th class="blank col35" >&nbsp;</th>
#       <th class="blank col36" >&nbsp;</th>
#       <th class="blank col37" >&nbsp;</th>
#       <th class="blank col38" >&nbsp;</th>
#       <th class="blank col39" >&nbsp;</th>
#       <th class="blank col40" >&nbsp;</th>
#       <th class="blank col41" >&nbsp;</th>
#       <th class="blank col42" >&nbsp;</th>
#       <th class="blank col43" >&nbsp;</th>
#       <th class="blank col44" >&nbsp;</th>
#       <th class="blank col45" >&nbsp;</th>
#       <th class="blank col46" >&nbsp;</th>
#       <th class="blank col47" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9777f_level0_row0" class="row_heading level0 row0" >Jardinería y paisajismo</th>
#       <td id="T_9777f_row0_col0" class="data row0 col0" >161</td>
#       <td id="T_9777f_row0_col1" class="data row0 col1" >87</td>
#       <td id="T_9777f_row0_col2" class="data row0 col2" >277</td>
#       <td id="T_9777f_row0_col3" class="data row0 col3" >323</td>
#       <td id="T_9777f_row0_col4" class="data row0 col4" >270</td>
#       <td id="T_9777f_row0_col5" class="data row0 col5" >273</td>
#       <td id="T_9777f_row0_col6" class="data row0 col6" >348</td>
#       <td id="T_9777f_row0_col7" class="data row0 col7" >339</td>
#       <td id="T_9777f_row0_col8" class="data row0 col8" >549</td>
#       <td id="T_9777f_row0_col9" class="data row0 col9" >276</td>
#       <td id="T_9777f_row0_col10" class="data row0 col10" >716</td>
#       <td id="T_9777f_row0_col11" class="data row0 c

# %%
columnas = {
              'selector':'.col_heading',
              'props':'font-weight: normal; font-family: Arial'
}

tabla = {
              'selector':'td,th',
              'props':'text-align: center'
}

indices = {
              'selector':'.index_name',
              'props':'font-weight: bold; font-family: Arial; text-align: right'
}

estilo_mensual.set_table_styles([columnas, tabla, indices], overwrite = False)
estilo_mensual
# Out:
# <style type="text/css">
# #T_9777f .col_heading {
#   font-weight: normal;
#   font-family: Arial;
# }
# #T_9777f td {
#   text-align: center;
# }
# #T_9777f th {
#   text-align: center;
# }
# #T_9777f .index_name {
#   font-weight: bold;
#   font-family: Arial;
#   text-align: right;
# }
# #T_9777f .col_heading {
#   font-weight: normal;
#   font-family: Arial;
# }
# #T_9777f td {
#   text-align: center;
# }
# #T_9777f th {
#   text-align: center;
# }
# #T_9777f .index_name {
#   font-weight: bold;
#   font-family: Arial;
#   text-align: right;
# }
# #T_9777f thead tr th:nth-child(1) {
#   position: sticky;
#   background-color: inherit;
#   left: 0px;
#   z-index: 3 !important;
# }
# #T_9777f tbody tr th:nth-child(1) {
#   position: sticky;
#   background-color: inherit;
#   left: 0px;
#   z-index: 1;
# }
# #T_9777f .col_heading {
#   font-weight: normal;
#   font-family: Arial;
# }
# #T_9777f td {
#   text-align: center;
# }
# #T_9777f th {
#   text-align: center;
# }
# #T_9777f .index_name {
#   font-weight: bold;
#   font-family: Arial;
#   text-align: right;
# }
# </style>
# <table id="T_9777f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >mes</th>
#       <th id="T_9777f_level0_col0" class="col_heading level0 col0" >2016 - Jan</th>
#       <th id="T_9777f_level0_col1" class="col_heading level0 col1" >2016 - Feb</th>
#       <th id="T_9777f_level0_col2" class="col_heading level0 col2" >2016 - Mar</th>
#       <th id="T_9777f_level0_col3" class="col_heading level0 col3" >2016 - Apr</th>
#       <th id="T_9777f_level0_col4" class="col_heading level0 col4" >2016 - May</th>
#       <th id="T_9777f_level0_col5" class="col_heading level0 col5" >2016 - Jun</th>
#       <th id="T_9777f_level0_col6" class="col_heading level0 col6" >2016 - Jul</th>
#       <th id="T_9777f_level0_col7" class="col_heading level0 col7" >2016 - Aug</th>
#       <th id="T_9777f_level0_col8" class="col_heading level0 col8" >2016 - Sep</th>
#       <th id="T_9777f_level0_col9" class="col_heading level0 col9" >2016 - Oct</th>
#       <th id="T_9777f_level0_col10" class="col_heading level0 col10" >2016 - Nov</th>
#       <th id="T_9777f_level0_col11" class="col_heading level0 col11" >2016 - Dec</th>
#       <th id="T_9777f_level0_col12" class="col_heading level0 col12" >2017 - Jan</th>
#       <th id="T_9777f_level0_col13" class="col_heading level0 col13" >2017 - Feb</th>
#       <th id="T_9777f_level0_col14" class="col_heading level0 col14" >2017 - Mar</th>
#       <th id="T_9777f_level0_col15" class="col_heading level0 col15" >2017 - Apr</th>
#       <th id="T_9777f_level0_col16" class="col_heading level0 col16" >2017 - May</th>
#       <th id="T_9777f_level0_col17" class="col_heading level0 col17" >2017 - Jun</th>
#       <th id="T_9777f_level0_col18" class="col_heading level0 col18" >2017 - Jul</th>
#       <th id="T_9777f_level0_col19" class="col_heading level0 col19" >2017 - Aug</th>
#       <th id="T_9777f_level0_col20" class="col_heading level0 col20" >2017 - Sep</th>
#       <th id="T_9777f_level0_col21" class="col_heading level0 col21" >2017 - Oct</th>
#       <th id="T_9777f_level0_col22" class="col_heading level0 col22" >2017 - Nov</th>
#       <th id="T_9777f_level0_col23" class="col_heading level0 col23" >2017 - Dec</th>
#       <th id="T_9777f_level0_col24" class="col_heading level0 col24" >2018 - Jan</th>
#       <th id="T_9777f_level0_col25" class="col_heading level0 col25" >2018 - Feb</th>
#       <th id="T_9777f_level0_col26" class="col_heading level0 col26" >2018 - Mar</th>
#       <th id="T_9777f_level0_col27" class="col_heading level0 col27" >2018 - Apr</th>
#       <th id="T_9777f_level0_col28" class="col_heading level0 col28" >2018 - May</th>
#       <th id="T_9777f_level0_col29" class="col_heading level0 col29" >2018 - Jun</th>
#       <th id="T_9777f_level0_col30" class="col_heading level0 col30" >2018 - Jul</th>
#       <th id="T_9777f_level0_col31" class="col_heading level0 col31" >2018 - Aug</th>
#       <th id="T_9777f_level0_col32" class="col_heading level0 col32" >2018 - Sep</th>
#       <th id="T_9777f_level0_col33" class="col_heading level0 col33" >2018 - Oct</th>
#       <th id="T_9777f_level0_col34" class="col_heading level0 col34" >2018 - Nov</th>
#       <th id="T_9777f_level0_col35" class="col_heading level0 col35" >2018 - Dec</th>
#       <th id="T_9777f_level0_col36" class="col_heading level0 col36" >2019 - Jan</th>
#       <th id="T_9777f_level0_col37" class="col_heading level0 col37" >2019 - Feb</th>
#       <th id="T_9777f_level0_col38" class="col_heading level0 col38" >2019 - Mar</th>
#       <th id="T_9777f_level0_col39" class="col_heading level0 col39" >2019 - Apr</th>
#       <th id="T_9777f_level0_col40" class="col_heading level0 col40" >2019 - May</th>
#       <th id="T_9777f_level0_col41" class="col_heading level0 col41" >2019 - Jun</th>
#       <th id="T_9777f_level0_col42" class="col_heading level0 col42" >2019 - Jul</th>
#       <th id="T_9777f_level0_col43" class="col_heading level0 col43" >2019 - Aug</th>
#       <th id="T_9777f_level0_col44" class="col_heading level0 col44" >2019 - Sep</th>
#       <th id="T_9777f_level0_col45" class="col_heading level0 col45" >2019 - Oct</th>
#       <th id="T_9777f_level0_col46" class="col_heading level0 col46" >2019 - Nov</th>
#       <th id="T_9777f_level0_col47" class="col_heading level0 col47" >2019 - Dec</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >departamento</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#       <th class="blank col18" >&nbsp;</th>
#       <th class="blank col19" >&nbsp;</th>
#       <th class="blank col20" >&nbsp;</th>
#       <th class="blank col21" >&nbsp;</th>
#       <th class="blank col22" >&nbsp;</th>
#       <th class="blank col23" >&nbsp;</th>
#       <th class="blank col24" >&nbsp;</th>
#       <th class="blank col25" >&nbsp;</th>
#       <th class="blank col26" >&nbsp;</th>
#       <th class="blank col27" >&nbsp;</th>
#       <th class="blank col28" >&nbsp;</th>
#       <th class="blank col29" >&nbsp;</th>
#       <th class="blank col30" >&nbsp;</th>
#       <th class="blank col31" >&nbsp;</th>
#       <th class="blank col32" >&nbsp;</th>
#       <th class="blank col33" >&nbsp;</th>
#       <th class="blank col34" >&nbsp;</th>
#       <th class="blank col35" >&nbsp;</th>
#       <th class="blank col36" >&nbsp;</th>
#       <th class="blank col37" >&nbsp;</th>
#       <th class="blank col38" >&nbsp;</th>
#       <th class="blank col39" >&nbsp;</th>
#       <th class="blank col40" >&nbsp;</th>
#       <th class="blank col41" >&nbsp;</th>
#       <th class="blank col42" >&nbsp;</th>
#       <th class="blank col43" >&nbsp;</th>
#       <th class="blank col44" >&nbsp;</th>
#       <th class="blank col45" >&nbsp;</th>
#       <th class="blank col46" >&nbsp;</th>
#       <th class="blank col47" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9777f_level0_row0" class="row_heading level0 row0" >Jardinería y paisajismo</th>
#       <td id="T_9777f_row0_col0" class="data row0 col0" >161</td>
#       <td id="T_9777f_row0_col1" class="data row0 col1" >87</td>
#       <td id="T_9777f_row0_col2" class="data row0 col2" >277</td>
#       <td id="T_9777f_row0_col3" class="data row0 col3" >323</td>
#       <td id="T_9777f_row0_col4" class="data row0 col4" >270</td>
#       <td id="T_9777f_row0_col5" class="data row0 col5" >273</td>
#       <td id="T_9777f_row0_col6" class="data row0 col6" >348</td>
#       <td id="T_9777f_row0_col7" class="data row0 col7" >339</td>
#       <td id="T_

# %% [markdown]
# # Misión 5: Informe de Desempeño
#
# El informe de desempeño es un documento muy importante para la empresa. En este, todos los que trabajan en la tienda pueden entender cómo está la empresa. Debido a ello, las tablas bien construídas son esenciales para mostrar los datos de la mejor forma.
#
# Por lo tanto, necesitamos construir una visualización que permita entender la **relación entre tipos de clientes y modo de envío de productos de acuerdo con las ventas**. De esta forma, será posible destacar en el informe cuál es el modo de envío y cuáles son los que más generaron lucro en las ventas.

# %%
df_cliente = ventas.pivot_table(index="segmento_cliente", columns="modo_envio", values="ventas", aggfunc="sum", sort=False)
df_cliente
# Out:
# modo_envio        Económica  Entrega estándar  Envío rápido  \
# segmento_cliente
# B2C               729174.73        2248283.69     498294.88
# B2B               718461.22        1884738.56     602049.40
#
# modo_envio        Entrega en 24 horas
# segmento_cliente
# B2C                         182531.47
# B2B                         217465.60

# %%
df_cliente["Total"] = df_cliente.sum(axis=1)
df_cliente.loc["Total"] = df_cliente.sum()
df_cliente
# Out:
# modo_envio         Económica  Entrega estándar  Envío rápido  \
# segmento_cliente
# B2C                729174.73        2248283.69     498294.88
# B2B                718461.22        1884738.56     602049.40
# Total             1447635.95        4133022.25    1100344.28
#
# modo_envio        Entrega en 24 horas        Total
# segmento_cliente
# B2C                         182531.47   7316569.54
# B2B                         217465.60   6845429.56
# Total                       399997.07  14161999.10

# %%
compra_cliente = df_cliente.style.format("{:,.0f}")
compra_cliente
# Out:
# <style type="text/css">
# </style>
# <table id="T_b4e2d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >modo_envio</th>
#       <th id="T_b4e2d_level0_col0" class="col_heading level0 col0" >Económica</th>
#       <th id="T_b4e2d_level0_col1" class="col_heading level0 col1" >Entrega estándar</th>
#       <th id="T_b4e2d_level0_col2" class="col_heading level0 col2" >Envío rápido</th>
#       <th id="T_b4e2d_level0_col3" class="col_heading level0 col3" >Entrega en 24 horas</th>
#       <th id="T_b4e2d_level0_col4" class="col_heading level0 col4" >Total</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >segmento_cliente</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b4e2d_level0_row0" class="row_heading level0 row0" >B2C</th>
#       <td id="T_b4e2d_row0_col0" class="data row0 col0" >729,175</td>
#       <td id="T_b4e2d_row0_col1" class="data row0 col1" >2,248,284</td>
#       <td id="T_b4e2d_row0_col2" class="data row0 col2" >498,295</td>
#       <td id="T_b4e2d_row0_col3" class="data row0 col3" >182,531</td>
#       <td id="T_b4e2d_row0_col4" class="data row0 col4" >7,316,570</td>
#     </tr>
#     <tr>
#       <th id="T_b4e2d_level0_row1" class="row_heading level0 row1" >B2B</th>
#       <td id="T_b4e2d_row1_col0" class="data row1 col0" >718,461</td>
#       <td id="T_b4e2d_row1_col1" class="data row1 col1" >1,884,739</td>
#       <td id="T_b4e2d_row1_col2" class="data row1 col2" >602,049</td>
#       <td id="T_b4e2d_row1_col3" class="data row1 col3" >217,466</td>
#       <td id="T_b4e2d_row1_col4" class="data row1 col4" >6,845,430</td>
#     </tr>
#     <tr>
#       <th id="T_b4e2d_level0_row2" class="row_heading level0 row2" >Total</th>
#       <td id="T_b4e2d_row2_col0" class="data row2 col0" >1,447,636</td>
#       <td id="T_b4e2d_row2_col1" class="data row2 col1" >4,133,022</td>
#       <td id="T_b4e2d_row2_col2" class="data row2 col2" >1,100,344</td>
#       <td id="T_b4e2d_row2_col3" class="data row2 col3" >399,997</td>
#       <td id="T_b4e2d_row2_col4" class="data row2 col4" >14,161,999</td>
#     </tr>
#   </tbody>
# </table>

# %%
tabla = {
              'selector':'.index_name',
              'props':'font-weight: normal; font-family: Arial; text-align: center; background-color: white'
}

indice = {
              'selector':'td,th:not(.index_name)',
              'props':'font-weight: normal; font-style: italic; text-align: right; color: #696969'
}

compra_cliente.set_table_styles([tabla, indice])
compra_cliente
# Out:
# <style type="text/css">
# #T_b4e2d .index_name {
#   font-weight: normal;
#   font-family: Arial;
#   text-align: center;
#   background-color: white;
# }
# #T_b4e2d td {
#   font-weight: normal;
#   font-style: italic;
#   text-align: right;
#   color: #696969;
# }
# #T_b4e2d th:not(.index_name) {
#   font-weight: normal;
#   font-style: italic;
#   text-align: right;
#   color: #696969;
# }
# </style>
# <table id="T_b4e2d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >modo_envio</th>
#       <th id="T_b4e2d_level0_col0" class="col_heading level0 col0" >Económica</th>
#       <th id="T_b4e2d_level0_col1" class="col_heading level0 col1" >Entrega estándar</th>
#       <th id="T_b4e2d_level0_col2" class="col_heading level0 col2" >Envío rápido</th>
#       <th id="T_b4e2d_level0_col3" class="col_heading level0 col3" >Entrega en 24 horas</th>
#       <th id="T_b4e2d_level0_col4" class="col_heading level0 col4" >Total</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >segmento_cliente</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b4e2d_level0_row0" class="row_heading level0 row0" >B2C</th>
#       <td id="T_b4e2d_row0_col0" class="data row0 col0" >729,175</td>
#       <td id="T_b4e2d_row0_col1" class="data row0 col1" >2,248,284</td>
#       <td id="T_b4e2d_row0_col2" class="data row0 col2" >498,295</td>
#       <td id="T_b4e2d_row0_col3" class="data row0 col3" >182,531</td>
#       <td id="T_b4e2d_row0_col4" class="data row0 col4" >7,316,570</td>
#     </tr>
#     <tr>
#       <th id="T_b4e2d_level0_row1" class="row_heading level0 row1" >B2B</th>
#       <td id="T_b4e2d_row1_col0" class="data row1 col0" >718,461</td>
#       <td id="T_b4e2d_row1_col1" class="data row1 col1" >1,884,739</td>
#       <td id="T_b4e2d_row1_col2" class="data row1 col2" >602,049</td>
#       <td id="T_b4e2d_row1_col3" class="data row1 col3" >217,466</td>
#       <td id="T_b4e2d_row1_col4" class="data row1 col4" >6,845,430</td>
#     </tr>
#     <tr>
#       <th id="T_b4e2d_level0_row2" class="row_heading level0 row2" >Total</th>
#       <td id="T_b4e2d_row2_col0" class="data row2 col0" >1,447,636</td>
#       <td id="T_b4e2d_row2_col1" class="data row2 col1" >4,133,022</td>
#       <td id="T_b4e2d_row2_col2" class="data row2 col2" >1,100,344</td>
#       <td id="T_b4e2d_row2_col3" class="data row2 col3" >399,997</td>
#       <td id="T_b4e2d_row2_col4" class="data row2 col4" >14,161,999</td>
#     </tr>
#   </tbody>
# </table>

# %%
compra_cliente.set_table_styles({
    "Total":[
        {
            'selector':'th',
          'props':'border-top: 2px solid #181818'
        }
    ],
    "B2B": [
        {
            'selector':'th',
          'props':'border-top: 2px solid #181818'
        }
    ]
}, overwrite = False, axis = 1)
# Out:
# <style type="text/css">
# #T_b4e2d .index_name {
#   font-weight: normal;
#   font-family: Arial;
#   text-align: center;
#   background-color: white;
# }
# #T_b4e2d td {
#   font-weight: normal;
#   font-style: italic;
#   text-align: right;
#   color: #696969;
# }
# #T_b4e2d th:not(.index_name) {
#   font-weight: normal;
#   font-style: italic;
#   text-align: right;
#   color: #696969;
# }
# #T_b4e2d th.row2 {
#   border-top: 2px solid #181818;
# }
# #T_b4e2d th.row1 {
#   border-top: 2px solid #181818;
# }
# </style>
# <table id="T_b4e2d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >modo_envio</th>
#       <th id="T_b4e2d_level0_col0" class="col_heading level0 col0" >Económica</th>
#       <th id="T_b4e2d_level0_col1" class="col_heading level0 col1" >Entrega estándar</th>
#       <th id="T_b4e2d_level0_col2" class="col_heading level0 col2" >Envío rápido</th>
#       <th id="T_b4e2d_level0_col3" class="col_heading level0 col3" >Entrega en 24 horas</th>
#       <th id="T_b4e2d_level0_col4" class="col_heading level0 col4" >Total</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >segmento_cliente</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b4e2d_level0_row0" class="row_heading level0 row0" >B2C</th>
#       <td id="T_b4e2d_row0_col0" class="data row0 col0" >729,175</td>
#       <td id="T_b4e2d_row0_col1" class="data row0 col1" >2,248,284</td>
#       <td id="T_b4e2d_row0_col2" class="data row0 col2" >498,295</td>
#       <td id="T_b4e2d_row0_col3" class="data row0 col3" >182,531</td>
#       <td id="T_b4e2d_row0_col4" class="data row0 col4" >7,316,570</td>
#     </tr>
#     <tr>
#       <th id="T_b4e2d_level0_row1" class="row_heading level0 row1" >B2B</th>
#       <td id="T_b4e2d_row1_col0" class="data row1 col0" >718,461</td>
#       <td id="T_b4e2d_row1_col1" class="data row1 col1" >1,884,739</td>
#       <td id="T_b4e2d_row1_col2" class="data row1 col2" >602,049</td>
#       <td id="T_b4e2d_row1_col3" class="data row1 col3" >217,466</td>
#       <td id="T_b4e2d_row1_col4" class="data row1 col4" >6,845,430</td>
#     </tr>
#     <tr>
#       <th id="T_b4e2d_level0_row2" class="row_heading level0 row2" >Total</th>
#       <td id="T_b4e2d_row2_col0" class="data row2 col0" >1,447,636</td>
#       <td id="T_b4e2d_row2_col1" class="data row2 col1" >4,133,022</td>
#       <td id="T_b4e2d_row2_col2" class="data row2 col2" >1,100,344</td>
#       <td id="T_b4e2d_row2_col3" class="data row2 col3" >399,997</td>
#       <td id="T_b4e2d_row2_col4" class="data row2 col4" >14,161,999</td>
#     </tr>
#   </tbody>
# </table>

# %%
compra_cliente.set_table_styles({
    'Total': [{
        'selector': '.true',
        'props': 'background-color: #D8D8D8'
    }]
}, overwrite = False, axis = 0)

colores_columna = pd.DataFrame(["false", "true", "false"], index = df_cliente["Total"]. index, columns = ["Total"])

compra_cliente.set_td_classes(colores_columna)
# Out:
# <style type="text/css">
# #T_b4e2d .index_name {
#   font-weight: normal;
#   font-family: Arial;
#   text-align: center;
#   background-color: white;
# }
# #T_b4e2d td {
#   font-weight: normal;
#   font-style: italic;
#   text-align: right;
#   color: #696969;
# }
# #T_b4e2d th:not(.index_name) {
#   font-weight: normal;
#   font-style: italic;
#   text-align: right;
#   color: #696969;
# }
# #T_b4e2d th.row2 {
#   border-top: 2px solid #181818;
# }
# #T_b4e2d th.row1 {
#   border-top: 2px solid #181818;
# }
# #T_b4e2d .true.col4 {
#   background-color: #D8D8D8;
# }
# #T_b4e2d .true.col4 {
#   background-color: #D8D8D8;
# }
# #T_b4e2d .true.col4 {
#   background-color: #D8D8D8;
# }
# #T_b4e2d .true.col4 {
#   background-color: #D8D8D8;
# }
# #T_b4e2d .true.col4 {
#   background-color: #D8D8D8;
# }
# </style>
# <table id="T_b4e2d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >modo_envio</th>
#       <th id="T_b4e2d_level0_col0" class="col_heading level0 col0" >Económica</th>
#       <th id="T_b4e2d_level0_col1" class="col_heading level0 col1" >Entrega estándar</th>
#       <th id="T_b4e2d_level0_col2" class="col_heading level0 col2" >Envío rápido</th>
#       <th id="T_b4e2d_level0_col3" class="col_heading level0 col3" >Entrega en 24 horas</th>
#       <th id="T_b4e2d_level0_col4" class="col_heading level0 col4" >Total</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >segmento_cliente</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b4e2d_level0_row0" class="row_heading level0 row0" >B2C</th>
#       <td id="T_b4e2d_row0_col0" class="data row0 col0" >729,175</td>
#       <td id="T_b4e2d_row0_col1" class="data row0 col1" >2,248,284</td>
#       <td id="T_b4e2d_row0_col2" class="data row0 col2" >498,295</td>
#       <td id="T_b4e2d_row0_col3" class="data row0 col3" >182,531</td>
#       <td id="T_b4e2d_row0_col4" class="data row0 col4 false" >7,316,570</td>
#     </tr>
#     <tr>
#       <th id="T_b4e2d_level0_row1" class="row_heading level0 row1" >B2B</th>
#       <td id="T_b4e2d_row1_col0" class="data row1 col0" >718,461</td>
#       <td id="T_b4e2d_row1_col1" class="data row1 col1" >1,884,739</td>
#       <td id="T_b4e2d_row1_col2" class="data row1 col2" >602,049</td>
#       <td id="T_b4e2d_row1_col3" class="data row1 col3" >217,466</td>
#       <td id="T_b4e2d_row1_col4" class="data row1 col4 true" >6,845,430</td>
#     </tr>
#     <tr>
#       <th id="T_b4e2d_level0_row2" class="row_heading level0 row2" >Total</th>
#       <td id="T_b4e2d_row2_col0" class="data row2 col0" >1,447,636</td>
#       <td id="T_b4e2d_row2_col1" class="data row2 col1" >4,133,022</td>
#       <td id="T_b4e2d_row2_col2" class="data row2 col2" >1,100,344</td>
#       <td id="T_b4e2d_row2_col3" class="data row2 col3" >399,997</td>
#       <td id="T_b4e2d_row2_col4" class="data row2 col4 false" >14,161,999</td>
#     </tr>
#   </tbody>
# </table>
