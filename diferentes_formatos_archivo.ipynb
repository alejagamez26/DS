# %% [markdown]
# <a href="https://colab.research.google.com/github/alejagamez26/DS/blob/main/diferentes_formatos_archivo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Leyendo archivos CSV**

# %% [markdown]
# ## **Importando archivos CSV**

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-6777fe24-1b9b-4bac-bd9e-de0eb8f74753" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6777fe24-1b9b-4bac-bd9e-de0eb8f74753">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# %%
datos = pd.read_csv('social_media_performance.csv')

# %%
datos.head()
# Out:
#    post_id  platform content_type       topic language region  \
# 0        1  LinkedIn      article  Technology       UR     BR
# 1        2  LinkedIn         poll      Health       FR     JP
# 2        3  LinkedIn      article      Travel       HI     FR
# 3        4  LinkedIn        image      Sports       DE     DE
# 4        5  LinkedIn         poll    Business       DE     US
#
#          post_datetime                                           hashtags  \
# 0  2025-04-25 09:47:00  #AI #Innovation #TechTrends #Programming #Codi...
# 1  2025-10-29 09:44:00  #Fitness #Nutrition #Wellness #Health #MentalH...
# 2  2025-02-10 14:12:00  #Travel #Journey #Adventure #Tourism #ExploreM...
# 3  2025-04-18 22:41:00                         #Cricket #Workout #Fitness
# 4  2025-04-28 10:17:00             #Entrepreneur #Leadership #StartupLife
#
#    sentiment_score  views  likes  comments  shares  engagement_rate  is_viral
# ...

# %%
datos_primeras_filas = pd.read_csv('social_media_performance.csv', nrows = 6)
datos_primeras_filas
# Out:
#    post_id  platform content_type       topic language region  \
# 0        1  LinkedIn      article  Technology       UR     BR
# 1        2  LinkedIn         poll      Health       FR     JP
# 2        3  LinkedIn      article      Travel       HI     FR
# 3        4  LinkedIn        image      Sports       DE     DE
# 4        5  LinkedIn         poll    Business       DE     US
# 5        6  LinkedIn        image      Sports       FR     AU
#
#          post_datetime                                           hashtags  \
# 0  2025-04-25 09:47:00  #AI #Innovation #TechTrends #Programming #Codi...
# 1  2025-10-29 09:44:00  #Fitness #Nutrition #Wellness #Health #MentalH...
# 2  2025-02-10 14:12:00  #Travel #Journey #Adventure #Tourism #ExploreM...
# 3  2025-04-18 22:41:00                         #Cricket #Workout #Fitness
# 4  2025-04-28 10:17:00             #Entrepreneur #Leadership #StartupLife
# 5  2025-10-03 15:25:00    #Fitness #Training #Cricket #Basketball #Sports
#
# ...

# %%
datos_mejor_contenido = pd.read_csv('social_media_performance.csv', usecols = ["platform", "content_type", "engagement_rate"])
datos_mejor_contenido
# Out:
#       platform content_type  engagement_rate
# 0     LinkedIn      article           0.0490
# 1     LinkedIn         poll           0.0915
# 2     LinkedIn      article           0.0833
# 3     LinkedIn        image           0.0675
# 4     LinkedIn         poll           0.0797
# ...        ...          ...              ...
# 9995   YouTube        video           0.1404
# 9996   YouTube        video           0.0344
# 9997   YouTube        video           0.0587
# 9998   YouTube        video           0.1321
# 9999   YouTube        video           0.0545
#
# [10000 rows x 3 columns]

# %% [markdown]
# ## **Escribiendo archivos CSV**

# %%
datos_mejor_contenido.to_csv("mejor_contenido.csv")

# %%
mejor_contenido = pd.read_csv("mejor_contenido.csv")
mejor_contenido
# Out:
#       Unnamed: 0  platform content_type  engagement_rate
# 0              0  LinkedIn      article           0.0490
# 1              1  LinkedIn         poll           0.0915
# 2              2  LinkedIn      article           0.0833
# 3              3  LinkedIn        image           0.0675
# 4              4  LinkedIn         poll           0.0797
# ...          ...       ...          ...              ...
# 9995        9995   YouTube        video           0.1404
# 9996        9996   YouTube        video           0.0344
# 9997        9997   YouTube        video           0.0587
# 9998        9998   YouTube        video           0.1321
# 9999        9999   YouTube        video           0.0545
#
# [10000 rows x 4 columns]

# %%
datos_mejor_contenido.to_csv("datos_mejor_contenido.csv", index = False )

# %%
datos_2_mejor_contenido = pd.read_csv("datos_mejor_contenido.csv")
datos_2_mejor_contenido
# Out:
#       platform content_type  engagement_rate
# 0     LinkedIn      article           0.0490
# 1     LinkedIn         poll           0.0915
# 2     LinkedIn      article           0.0833
# 3     LinkedIn        image           0.0675
# 4     LinkedIn         poll           0.0797
# ...        ...          ...              ...
# 9995   YouTube        video           0.1404
# 9996   YouTube        video           0.0344
# 9997   YouTube        video           0.0587
# 9998   YouTube        video           0.1321
# 9999   YouTube        video           0.0545
#
# [10000 rows x 3 columns]

# %% [markdown]
# # **Leyendo archivos Excel**

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-4c71f723-cf7e-4979-9cfe-dfe569bd7559" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4c71f723-cf7e-4979-9cfe-dfe569bd7559">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# %%
archivo = "Cola.xlsx"

# %%
datos_cocacola = pd.read_excel(archivo)

# %%
datos_cocacola.head()
# Out:
#    Data provided by SimFin              Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                      NaN                     NaN        NaN        NaN
# 1  Profit & Loss statement                     NaN        NaN        NaN
# 2                      NaN          in million USD     FY '09     FY '10
# 3                      NaN  NET OPERATING REVENUES      30990      35119
# 4                      NaN      Cost of goods sold      11088      12693
#
#   Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2     FY '11     FY '12     FY '13     FY '14     FY '15     FY '16
# 3      46542      48017      46854      45998      44294      41863
# 4      18215      19053      18421      17889      17482      16465
#
#   Unnamed: 10 Unnamed: 11
# 0         NaN         NaN
# 1         NaN         NaN
# 2      FY '17      FY '18
# ...

# %%
pd.ExcelFile(archivo).sheet_names
# Out:
# ['COCA COLA CO']

# %% [markdown]
# ## **Parametros función .read_excel**

# %%
# para abrir otra hoja diferente a la primera

pd.real_excel(archivo, sheet_name = "")

# %% [markdown]
# # **Leyendo datos de Google Sheets"**

# %%
# Crear una variable con el id del sheets
# Copiar la url del sheets

sheet_id =
url =

# %% [markdown]
# # **Leyendo archivos JSON**

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-cae02961-0998-48cc-89bf-5097cfc54c4f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cae02961-0998-48cc-89bf-5097cfc54c4f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
datos_pacientes_1 = pd.read_json("pacientes.json")

# %%
datos_pacientes_1
# Out:
#      ID_paciente Enfermedad_corazon    IMC Fumador Consumo_alcohol AVC  \
# 0              0                 No  16.60      Sí              No  No
# 1              1                 No  20.34      No              No  Sí
# 2              2                 No  26.58      Sí              No  No
# 3              3                 No  24.21      No              No  No
# 4              4                 No  23.71      No              No  No
# ..           ...                ...    ...     ...             ...  ..
# 995          995                 No  28.29      Sí              No  No
# 996          996                 No  25.69      Sí              No  No
# 997          997                 Sí  26.99      No              No  No
# 998          998                 No  44.29      No              No  No
# 999          999                 No  25.83      No              No  No
#
#      Salud_fisica  Salud_mental Dificultad_caminar Sexo_biologico Rango_edad  \
# ...

# %%
datos_pacientes_2 = pd.read_json("pacientes_2.json")

# %%
datos_pacientes_2
# Out:
#                                  Investigación   Año  \
# 0  Indicadores clave de enfermedades cardíacas  2020
# 1  Indicadores clave de enfermedades cardíacas  2020
# 2  Indicadores clave de enfermedades cardíacas  2020
#
#                                            Pacientes
# 0  {'ID': '01', 'Rango_edad': '55-59', 'Sexo_biol...
# 1  {'ID': '02', 'Rango_edad': '80 ó +', 'Sexo_bio...
# 2  {'ID': '03', 'Rango_edad': '65-69', 'Sexo_biol...

# %% [markdown]
# ## **Normalizando archivos json**

# %%
df_normalizado = pd.json_normalize(datos_pacientes_2["Pacientes"])

# %%
df_normalizado
# Out:
#    ID Rango_edad Sexo_biologico    Raza    IMC Fumador Consumo_alcohol  \
# 0  01      55-59          Mujer  Blanca  16.60      Sí              No
# 1  02     80 ó +          Mujer  Blanca  20.34      No              No
# 2  03      65-69      Masculino  Blanca  26.58      Sí              No
#
#    Salud_física  Salud_mental Dificultad_caminar Actividad_física  \
# 0             3            30                 No               Sí
# 1             0             0                 No               Sí
# 2            20            30                 No               Sí
#
#   Salud_general  Horas_sueño                Problemas_salud
# 0     Muy buena            5  [Diabetes, Asma, Cancer_piel]
# 1     Muy buena            7                          [AVC]
# 2     Muy buena            8               [Diabetes, Asma]

# %% [markdown]
# ## **Escribiendo archivos json**

# %%
df_normalizado.to_json("pacientes_normalizados.json")

# %% [markdown]
# # **Leyendo páginas en HTML e XML**

# %% [markdown]
# ## **Importando páginas web**

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-5b4c22a3-9be5-41cc-bb0a-fe79242ea06d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5b4c22a3-9be5-41cc-bb0a-fe79242ea06d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# %%
datos_html = pd.read_html("peliculas_wikipedia.html")

# %%
datos_html
# Out:
# [       0                      1
#  0   1998             100 Movies
#  1   1999              100 Stars
#  2   2000             100 Laughs
#  3   2001            100 Thrills
#  4   2002           100 Passions
#  5   2003  100 Heroes & Villains
#  6   2004              100 Songs
#  7   2005       100 Movie Quotes
#  8   2005              25 Scores
#  9   2006             100 Cheers
#  10  2006            25 Musicals
#  11  2007   100 Movies (Updated)
#  12  2008        AFI's 10 Top 10
#  13   vte                    vte,
#                              Film  Release year              Director  \
#  0                   Citizen Kane          1941          Orson Welles
#  1                     Casablanca          1942        Michael Curtiz
#  2                  The Godfather          1972  Francis Ford Coppola
#  3             Gone with the Wind          1939        Victor Fleming
#  4             Lawrence of Arabia          1962            David Lean
# ...

# %%
top_peliculas = datos_html[1]

# %%
top_peliculas
# Out:
#                             Film  Release year              Director  \
# 0                   Citizen Kane          1941          Orson Welles
# 1                     Casablanca          1942        Michael Curtiz
# 2                  The Godfather          1972  Francis Ford Coppola
# 3             Gone with the Wind          1939        Victor Fleming
# 4             Lawrence of Arabia          1962            David Lean
# ..                           ...           ...                   ...
# 95                 The Searchers          1956             John Ford
# 96              Bringing Up Baby          1938          Howard Hawks
# 97                    Unforgiven          1992        Clint Eastwood
# 98  Guess Who's Coming to Dinner          1967        Stanley Kramer
# 99           Yankee Doodle Dandy          1942        Michael Curtiz
#
#                       Production companies  Rank
# 0                       RKO Radio Pictures     1
# ...

# %% [markdown]
# ## **Escribiendo archivos HTML**

# %%
top_peliculas.to_html("top_peliculas.html")

# %% [markdown]
# # **Leyendo banco de datos**

# %% [markdown]
# ## **Creando un banco de datos local**

# %%
import sqlalchemy

# %%
from sqlalchemy import create_engine, MetaData, Table, inspect, text

# %%
engine = create_engine("sqlite:///:memory:")

# %% [markdown]
# ## **Escribiendo en un banco de datos**

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-cbaef2f9-646a-4bba-a4d2-e818f7be091c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cbaef2f9-646a-4bba-a4d2-e818f7be091c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# %%
archivo = "clientes_banco.csv"

# %%
datos = pd.read_csv(archivo)
datos
# Out:
#         ID_Cliente  Edad     Grado_estudio      Estado_civil  Tamaño_familia  \
# 0          5008804    32    Nivel superior  Relación-estable               2
# 1          5008805    32    Nivel superior  Relación-estable               2
# 2          5008806    58  Nivel intermedio            Casado               2
# 3          5008808    52  Nivel intermedio           Soltero               1
# 4          5008809    52  Nivel intermedio           Soltero               1
# ...            ...   ...               ...               ...             ...
# 438458     6840104    62  Nivel intermedio        Divorciado               1
# 438459     6840222    43  Nivel intermedio           Soltero               1
# 438460     6841878    22    Nivel superior           Soltero               1
# 438461     6842765    59  Nivel intermedio            Casado               2
# 438462     6842885    51  Nivel intermedio            Casado               2
#
# ...

# %%
datos.to_sql("clientes", engine, index=False)
# Out:
# 438463

# %% [markdown]
# ## **Leyendo una consulta SQL**

# %%
query = "SELECT * FROM clientes WHERE Categoria_de_renta = 'Empleado'"

# %%
pd.read_sql(query, engine)
# Out:
#         ID_Cliente  Edad     Grado_estudio      Estado_civil  Tamaño_familia  \
# 0          5008804    32    Nivel superior  Relación-estable               2
# 1          5008805    32    Nivel superior  Relación-estable               2
# 2          5008806    58  Nivel intermedio            Casado               2
# 3          5008815    46    Nivel superior            Casado               2
# 4          5112956    46    Nivel superior            Casado               2
# ...            ...   ...               ...               ...             ...
# 226054     6837905    43  Nivel intermedio            Casado               3
# 226055     6837906    43  Nivel intermedio            Casado               3
# 226056     6839936    34  Nivel intermedio            Casado               3
# 226057     6840222    43  Nivel intermedio           Soltero               1
# 226058     6842885    51  Nivel intermedio            Casado               2
#
# ...
